# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import collections
import pickle
import os


from training import *
from models import *
from A2C_agent import *
from helpers import *

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Load data and agents

# %%
# # Load all_* dictionaries
# with open('agent1_data/all_dicts.pkl', 'rb') as f:
#     all_critic_losses, all_actor_losses, all_episode_rewards, \
#         all_evaluation_reward_means, all_evaluation_reward_stds, all_evaluation_value_trajectories = pickle.load(f)

# # Load agent1 dictionary
# with open('agent1_data/agent1.pkl', 'rb') as f:
#     agent1 = pickle.load(f)

# %% [markdown]
# # 3.1 Agent 2: K-worker A2C version in CartPole
# ### K worker implementation (k=6)

# %%
# hyperparameters
stochastic_rewards = True
continuous = False
k=6
n=1
lr_actor=1e-5
lr_critic=1e-3
total_steps_budget = 500000
device = "cpu"
seeds = [77, 777, 7777]

agent, \
    all_critic_losses, all_actor_losses, all_episode_rewards, \
    all_evaluation_reward_means, all_evaluation_reward_stds, all_evaluation_value_trajectories \
        = training_loop(k, n, continuous, seeds, lr_actor, lr_critic, total_steps_budget, stochastic_rewards, device)
# Out:
# -------- Episode 100 ended with reward 16.00 for model 0 --------
# Actor loss: -0.7385, Critic loss: 4.4717
# Total steps taken during training: 1961
# -------- Episode 200 ended with reward 20.00 for model 0 --------
# Actor loss: -0.0781, Critic loss: 1.7726
# Total steps taken during training: 4155
# -------- Episode 300 ended with reward 38.00 for model 0 --------
# Actor loss: -0.2400, Critic loss: 0.8068
# Total steps taken during training: 6690
# -------- Episode 400 ended with reward 18.00 for model 0 --------
# Actor loss: -0.2797, Critic loss: 0.5173
# Total steps taken during training: 9562
# -------- Episode 500 ended with reward 28.00 for model 0 --------
# Actor loss: -0.5265, Critic loss: 0.9821
# Total steps taken during training: 12710
# -------- Episode 600 ended with reward 36.00 for model 0 --------
# Actor loss: -0.0014, Critic loss: 0.4468
# Total steps taken during training: 16235
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 179.10, Std reward: 137.78, total steps: 20004
# ----     Evaluation finished        ----
# -------- Episode 700 ended with reward 67.00 for model 0 --------
# Actor loss: -0.0599, Critic loss: 0.1489
# Total steps taken during training: 20343
# -------- Episode 800 ended with reward 38.00 for model 0 --------
# Actor loss: -0.6874, Critic loss: 0.8720
# Total steps taken during training: 24853
# -------- Episode 900 ended with reward 27.00 for model 0 --------
# Actor loss: -0.2599, Critic loss: 0.3713
# Total steps taken during training: 29873
# -------- Episode 1000 ended with reward 70.00 for model 0 --------
# Actor loss: -0.0608, Critic loss: 0.3050
# Total steps taken during training: 35661
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 232.50, Std reward: 178.09, total steps: 40002
# ----     Evaluation finished        ----
# -------- Episode 1100 ended with reward 55.00 for model 0 --------
# Actor loss: -0.7628, Critic loss: 2.4288
# Total steps taken during training: 42242
# -------- Episode 1200 ended with reward 76.00 for model 0 --------
# Actor loss: -0.2347, Critic loss: 0.6345
# Total steps taken during training: 50499
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 496.70, Std reward: 9.90, total steps: 60000
# ----     Evaluation finished        ----
# -------- Episode 1300 ended with reward 114.00 for model 0 --------
# Actor loss: -0.6475, Critic loss: 1.7668
# Total steps taken during training: 63805
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 490.30, Std reward: 29.10, total steps: 80004
# ----     Evaluation finished        ----
# -------- Episode 1400 ended with reward 230.00 for model 0 --------
# Actor loss: -0.2221, Critic loss: 1.9134
# Total steps taken during training: 81523
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 457.00, Std reward: 55.39, total steps: 100002
# ----     Evaluation finished        ----
# -------- Episode 1500 ended with reward 244.00 for model 0 --------
# Actor loss: -0.2245, Critic loss: 18.0934
# Total steps taken during training: 104490
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 120000
# ----     Evaluation finished        ----
# -------- Episode 1600 ended with reward 302.00 for model 0 --------
# Actor loss: -0.2600, Critic loss: 10.3203
# Total steps taken during training: 137180
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 498.60, Std reward: 4.20, total steps: 140004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 160002
# ----     Evaluation finished        ----
# -------- Episode 1700 ended with reward 381.00 for model 0 --------
# Actor loss: 0.2854, Critic loss: 7.6502
# Total steps taken during training: 169643
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 255.40, Std reward: 84.78, total steps: 180000
# ----     Evaluation finished        ----
# -------- Episode 1800 ended with reward 265.00 for model 0 --------
# Actor loss: -0.4279, Critic loss: 2.1528
# Total steps taken during training: 195026
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 470.20, Std reward: 60.03, total steps: 200004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 472.70, Std reward: 56.17, total steps: 220002
# ----     Evaluation finished        ----
# -------- Episode 1900 ended with reward 349.00 for model 0 --------
# Actor loss: -0.2006, Critic loss: 7.6016
# Total steps taken during training: 228825
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 240000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 481.20, Std reward: 37.60, total steps: 260004
# ----     Evaluation finished        ----
# -------- Episode 2000 ended with reward 500.00 for model 0 --------
# Actor loss: -0.1564, Critic loss: 0.1385
# Total steps taken during training: 269913
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 280002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 300000
# ----     Evaluation finished        ----
# -------- Episode 2100 ended with reward 498.00 for model 0 --------
# Actor loss: -0.3745, Critic loss: 3.4341
# Total steps taken during training: 310403
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 499.30, Std reward: 2.10, total steps: 320004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 340002
# ----     Evaluation finished        ----
# -------- Episode 2200 ended with reward 500.00 for model 0 --------
# Actor loss: -0.2496, Critic loss: 0.1202
# Total steps taken during training: 355754
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 479.60, Std reward: 43.39, total steps: 360000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 380004
# ----     Evaluation finished        ----
# -------- Episode 2300 ended with reward 463.00 for model 0 --------
# Actor loss: -0.2341, Critic loss: 15.5002
# Total steps taken during training: 399920
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 400002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 420000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 440004
# ----     Evaluation finished        ----
# -------- Episode 2400 ended with reward 500.00 for model 0 --------
# Actor loss: -0.1878, Critic loss: 0.1525
# Total steps taken during training: 446072
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 460002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 480000
# ----     Evaluation finished        ----
# -------- Episode 2500 ended with reward 500.00 for model 0 --------
# Actor loss: -0.1134, Critic loss: 0.1442
# Total steps taken during training: 494185
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 486.30, Std reward: 41.10, total steps: 500004
# ----     Evaluation finished        ----
# Reached total training budget of 500000 steps ----> Stopping training at episode 2511
# Experiment took 105.12s in total.
# -------- Episode 100 ended with reward 13.00 for model 1 --------
# Actor loss: -0.4869, Critic loss: 1.9312
# Total steps taken during training: 2233
# -------- Episode 200 ended with reward 64.00 for model 1 --------
# Actor loss: -1.0712, Critic loss: 5.2184
# Total steps taken during training: 4874
# -------- Episode 300 ended with reward 14.00 for model 1 --------
# Actor loss: 0.4407, Critic loss: 1.3110
# Total steps taken during training: 7668
# -------- Episode 400 ended with reward 82.00 for model 1 --------
# Actor loss: -0.5218, Critic loss: 2.7711
# Total steps taken during training: 10980
# -------- Episode 500 ended with reward 79.00 for model 1 --------
# Actor loss: 0.0766, Critic loss: 0.7457
# Total steps taken during training: 14590
# -------- Episode 600 ended with reward 39.00 for model 1 --------
# Actor loss: -0.6661, Critic loss: 0.6457
# Total steps taken during training: 18685
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 109.80, Std reward: 42.66, total steps: 20004
# ----     Evaluation finished        ----
# -------- Episode 700 ended with reward 107.00 for model 1 --------
# Actor loss: -0.0879, Critic loss: 0.1711
# Total steps taken during training: 24447
# -------- Episode 800 ended with reward 31.00 for model 1 --------
# Actor loss: -0.3870, Critic loss: 1.8380
# Total steps taken during training: 30306
# -------- Episode 900 ended with reward 74.00 for model 1 --------
# Actor loss: -0.1532, Critic loss: 6.8624
# Total steps taken during training: 37528
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 325.20, Std reward: 77.06, total steps: 40002
# ----     Evaluation finished        ----
# -------- Episode 1000 ended with reward 55.00 for model 1 --------
# Actor loss: -0.0008, Critic loss: 0.2981
# Total steps taken during training: 47397
# -------- Episode 1100 ended with reward 76.00 for model 1 --------
# Actor loss: -0.2863, Critic loss: 4.1913
# Total steps taken during training: 59707
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 471.80, Std reward: 57.18, total steps: 60000
# ----     Evaluation finished        ----
# -------- Episode 1200 ended with reward 169.00 for model 1 --------
# Actor loss: 0.1071, Critic loss: 0.3015
# Total steps taken during training: 78877
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 440.80, Std reward: 75.81, total steps: 80004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 489.80, Std reward: 30.60, total steps: 100002
# ----     Evaluation finished        ----
# -------- Episode 1300 ended with reward 240.00 for model 1 --------
# Actor loss: -0.3200, Critic loss: 1.2470
# Total steps taken during training: 103370
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 482.50, Std reward: 52.50, total steps: 120000
# ----     Evaluation finished        ----
# -------- Episode 1400 ended with reward 178.00 for model 1 --------
# Actor loss: -0.4144, Critic loss: 2.0878
# Total steps taken during training: 130403
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 327.70, Std reward: 105.65, total steps: 140004
# ----     Evaluation finished        ----
# -------- Episode 1500 ended with reward 241.00 for model 1 --------
# Actor loss: -0.4603, Critic loss: 1.4246
# Total steps taken during training: 153295
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 492.40, Std reward: 22.80, total steps: 160002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 422.50, Std reward: 72.66, total steps: 180000
# ----     Evaluation finished        ----
# -------- Episode 1600 ended with reward 470.00 for model 1 --------
# Actor loss: 0.7024, Critic loss: 4.0351
# Total steps taken during training: 184793
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 200004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 493.00, Std reward: 21.00, total steps: 220002
# ----     Evaluation finished        ----
# -------- Episode 1700 ended with reward 483.00 for model 1 --------
# Actor loss: -0.2665, Critic loss: 0.9476
# Total steps taken during training: 226273
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 240000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 260004
# ----     Evaluation finished        ----
# -------- Episode 1800 ended with reward 500.00 for model 1 --------
# Actor loss: -0.1422, Critic loss: 0.1177
# Total steps taken during training: 269074
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 280002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 300000
# ----     Evaluation finished        ----
# -------- Episode 1900 ended with reward 500.00 for model 1 --------
# Actor loss: 0.1872, Critic loss: 0.2021
# Total steps taken during training: 313167
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 320004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 469.90, Std reward: 68.17, total steps: 340002
# ----     Evaluation finished        ----
# -------- Episode 2000 ended with reward 124.00 for model 1 --------
# Actor loss: 0.2597, Critic loss: 0.5125
# Total steps taken during training: 349251
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 383.10, Std reward: 97.37, total steps: 360000
# ----     Evaluation finished        ----
# -------- Episode 2100 ended with reward 207.00 for model 1 --------
# Actor loss: -0.0658, Critic loss: 0.8054
# Total steps taken during training: 375011
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 458.90, Std reward: 50.58, total steps: 380004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 400002
# ----     Evaluation finished        ----
# -------- Episode 2200 ended with reward 500.00 for model 1 --------
# Actor loss: -0.1501, Critic loss: 0.1200
# Total steps taken during training: 419068
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 420000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 440004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 460002
# ----     Evaluation finished        ----
# -------- Episode 2300 ended with reward 500.00 for model 1 --------
# Actor loss: -0.2003, Critic loss: 0.1327
# Total steps taken during training: 465964
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 480000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 468.60, Std reward: 51.63, total steps: 500004
# ----     Evaluation finished        ----
# Reached total training budget of 500000 steps ----> Stopping training at episode 2380
# Experiment took 106.79s in total.
# -------- Episode 100 ended with reward 12.00 for model 2 --------
# Actor loss: -0.5999, Critic loss: 3.5090
# Total steps taken during training: 2408
# -------- Episode 200 ended with reward 21.00 for model 2 --------
# Actor loss: -0.3882, Critic loss: 2.3344
# Total steps taken during training: 5199
# -------- Episode 300 ended with reward 21.00 for model 2 --------
# Actor loss: -0.9328, Critic loss: 3.7641
# Total steps taken during training: 7864
# -------- Episode 400 ended with reward 36.00 for model 2 --------
# Actor loss: 0.0858, Critic loss: 0.9112
# Total steps taken during training: 11156
# -------- Episode 500 ended with reward 22.00 for model 2 --------
# Actor loss: -0.1916, Critic loss: 0.4527
# Total steps taken during training: 15223
# -------- Episode 600 ended with reward 13.00 for model 2 --------
# Actor loss: -0.6185, Critic loss: 1.6298
# Total steps taken during training: 19509
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 65.00, Std reward: 11.00, total steps: 20004
# ----     Evaluation finished        ----
# -------- Episode 700 ended with reward 37.00 for model 2 --------
# Actor loss: -0.4443, Critic loss: 0.7756
# Total steps taken during training: 24156
# -------- Episode 800 ended with reward 45.00 for model 2 --------
# Actor loss: -0.2013, Critic loss: 0.2938
# Total steps taken during training: 29694
# -------- Episode 900 ended with reward 49.00 for model 2 --------
# Actor loss: -0.4232, Critic loss: 1.3852
# Total steps taken during training: 36502
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 254.50, Std reward: 105.21, total steps: 40002
# ----     Evaluation finished        ----
# -------- Episode 1000 ended with reward 171.00 for model 2 --------
# Actor loss: -0.4266, Critic loss: 7.1297
# Total steps taken during training: 46994
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 423.90, Std reward: 72.28, total steps: 60000
# ----     Evaluation finished        ----
# -------- Episode 1100 ended with reward 67.00 for model 2 --------
# Actor loss: -0.2242, Critic loss: 11.0886
# Total steps taken during training: 62058
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 441.10, Std reward: 68.85, total steps: 80004
# ----     Evaluation finished        ----
# -------- Episode 1200 ended with reward 289.00 for model 2 --------
# Actor loss: -1.1384, Critic loss: 4.2661
# Total steps taken during training: 81624
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 448.70, Std reward: 68.04, total steps: 100002
# ----     Evaluation finished        ----
# -------- Episode 1300 ended with reward 394.00 for model 2 --------
# Actor loss: -0.3733, Critic loss: 2.5960
# Total steps taken during training: 109111
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 231.90, Std reward: 11.28, total steps: 120000
# ----     Evaluation finished        ----
# -------- Episode 1400 ended with reward 412.00 for model 2 --------
# Actor loss: -1.3261, Critic loss: 10.2389
# Total steps taken during training: 134119
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 314.00, Std reward: 64.85, total steps: 140004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 305.00, Std reward: 65.27, total steps: 160002
# ----     Evaluation finished        ----
# -------- Episode 1500 ended with reward 205.00 for model 2 --------
# Actor loss: -0.3038, Critic loss: 5.4418
# Total steps taken during training: 163998
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 482.60, Std reward: 26.53, total steps: 180000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 200004
# ----     Evaluation finished        ----
# -------- Episode 1600 ended with reward 500.00 for model 2 --------
# Actor loss: -0.1246, Critic loss: 11.0998
# Total steps taken during training: 201804
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 220002
# ----     Evaluation finished        ----
# -------- Episode 1700 ended with reward 206.00 for model 2 --------
# Actor loss: -0.3588, Critic loss: 2.6922
# Total steps taken during training: 236999
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 431.50, Std reward: 62.44, total steps: 240000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 443.90, Std reward: 49.98, total steps: 260004
# ----     Evaluation finished        ----
# -------- Episode 1800 ended with reward 473.00 for model 2 --------
# Actor loss: 0.4372, Critic loss: 0.8231
# Total steps taken during training: 273326
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 280002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 300000
# ----     Evaluation finished        ----
# -------- Episode 1900 ended with reward 282.00 for model 2 --------
# Actor loss: -0.4262, Critic loss: 5.9351
# Total steps taken during training: 317420
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 477.20, Std reward: 35.81, total steps: 320004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 463.90, Std reward: 56.40, total steps: 340002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 360000
# ----     Evaluation finished        ----
# -------- Episode 2000 ended with reward 500.00 for model 2 --------
# Actor loss: -0.0486, Critic loss: 0.1043
# Total steps taken during training: 360868
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 380004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 400002
# ----     Evaluation finished        ----
# -------- Episode 2100 ended with reward 500.00 for model 2 --------
# Actor loss: 0.6503, Critic loss: 0.4792
# Total steps taken during training: 407989
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 493.40, Std reward: 19.80, total steps: 420000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 470.00, Std reward: 60.00, total steps: 440004
# ----     Evaluation finished        ----
# -------- Episode 2200 ended with reward 473.00 for model 2 --------
# Actor loss: -0.4872, Critic loss: 14.9654
# Total steps taken during training: 454478
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 497.90, Std reward: 6.30, total steps: 460002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 480000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 500004
# ----     Evaluation finished        ----
# Reached total training budget of 500000 steps ----> Stopping training at episode 2299
# Experiment took 103.39s in total.

# %% [markdown]
# ### training logging info
#
# - losses and rewards are every 1k step
# - evaluation rewards and value_trajectories are every 20k steps

# %%
len(all_critic_losses[0]),len(all_critic_losses[1]),len(all_critic_losses[2])
# Out:
# (500, 500, 500)

# %%
# Get stats 
min_critic_losses, max_critic_losses, avg_critic_losses = get_stats(all_critic_losses)
min_actor_losses, max_actor_losses, avg_actor_losses = get_stats(all_actor_losses)
min_episode_rewards, max_episode_rewards, avg_episode_rewards = get_stats(all_episode_rewards)

save_plots = True
folder_name = 'agent2'

# Plot stats 
plot_stats(save_plots, folder_name, min_critic_losses, max_critic_losses, avg_critic_losses, title='Critic Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_stats(save_plots, folder_name, min_actor_losses, max_actor_losses, avg_actor_losses, title='Actor Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_stats(save_plots, folder_name, min_episode_rewards, max_episode_rewards, avg_episode_rewards, title='Episode Rewards', ylabel='Reward', xlabel='Steps (every 1000 steps)')

# %%
# Plot smoothed stats 
window_size = 10

plot_smoothed_stats(save_plots, folder_name, min_critic_losses, max_critic_losses, avg_critic_losses, window_size, title='Critic Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_smoothed_stats(save_plots, folder_name, min_actor_losses, max_actor_losses, avg_actor_losses, window_size, title='Actor Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_smoothed_stats(save_plots, folder_name, min_episode_rewards, max_episode_rewards, avg_episode_rewards, window_size, title='Episode Rewards', ylabel='Reward', xlabel='Steps (every 1000 steps)')

# %%
# Get stats for evaluation rewards
min_eval_rew, max_eval_rew, avg_eval_rew = get_stats(all_evaluation_reward_means)

# Plot stats
plot_smoothed_stats(save_plots, folder_name, min_eval_rew, max_eval_rew, avg_eval_rew, window_size, title='Evaluation Episode Rewards',ylabel='Reward',xlabel='Steps (every 20k steps)')

# %%
plot_and_save_trajectories(save_plots, folder_name, all_evaluation_value_trajectories, x_range=[0, 500], y_range=[0, 20])

# %% [markdown]
# ### saving agents and data

# %%
folder_name = "data/data_agent2"

os.makedirs(folder_name, exist_ok=True)

# # Save all_* dictionaries
with open(folder_name+'/all_dicts.pkl', 'wb') as f:
    pickle.dump([all_critic_losses, all_actor_losses, all_episode_rewards, \
                 all_evaluation_reward_means, all_evaluation_reward_stds, all_evaluation_value_trajectories], f)

# Save agent3 dictionary
with open(folder_name+'/agent.pkl', 'wb') as f:
    pickle.dump(agent, f)

# # Save seed list used for training
with open(folder_name+'/seeds.pkl', 'wb') as f:
    pickle.dump(seeds, f)
