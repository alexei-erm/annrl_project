# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import collections
import pickle
import os


from headers.training import *
from models import *
from A2C_agent import *
from helpers import *

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Load data and agents

# %%
# # Load all_* dictionaries
# with open('agent1_data/all_dicts.pkl', 'rb') as f:
#     all_critic_losses, all_actor_losses, all_episode_rewards, \
#         all_evaluation_reward_means, all_evaluation_reward_stds, all_evaluation_value_trajectories = pickle.load(f)

# # Load agent1 dictionary
# with open('agent1_data/agent1.pkl', 'rb') as f:
#     agent1 = pickle.load(f)

# %% [markdown]
# # 3.1 Agent 2: K-worker A2C version in CartPole
# ### K worker implementation (k=6)

# %%
# hyperparameters
stochastic_rewards = False
continuous = False
k=6
n=1
lr_actor=1e-5
lr_critic=1e-3
total_steps_budget = 500000
device = "cpu"
seeds = [77, 777, 7777]

agent, \
    all_critic_losses, all_actor_losses, all_episode_rewards, \
    all_evaluation_reward_means, all_evaluation_reward_stds, all_evaluation_value_trajectories \
        = training_loop(k, n, continuous, seeds, lr_actor, lr_critic, total_steps_budget, stochastic_rewards, device)
# Out:
# -------- Episode 100 ended with reward 22.00 for model 0 --------
# Actor loss: -5.0035, Critic loss: 163.9543
# Total steps taken during training: 2061
# -------- Episode 200 ended with reward 19.00 for model 0 --------
# Actor loss: -0.4477, Critic loss: 7.2474
# Total steps taken during training: 4223
# -------- Episode 300 ended with reward 21.00 for model 0 --------
# Actor loss: -5.7357, Critic loss: 314.8451
# Total steps taken during training: 6654
# -------- Episode 400 ended with reward 15.00 for model 0 --------
# Actor loss: -2.8683, Critic loss: 298.9127
# Total steps taken during training: 9146
# -------- Episode 500 ended with reward 10.00 for model 0 --------
# Actor loss: -2.8935, Critic loss: 199.2044
# Total steps taken during training: 11471
# -------- Episode 600 ended with reward 38.00 for model 0 --------
# Actor loss: -0.3096, Critic loss: 19.3212
# Total steps taken during training: 14121
# -------- Episode 700 ended with reward 24.00 for model 0 --------
# Actor loss: 0.9433, Critic loss: 32.5024
# Total steps taken during training: 16726
# -------- Episode 800 ended with reward 26.00 for model 0 --------
# Actor loss: -5.1928, Critic loss: 167.4327
# Total steps taken during training: 19689
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 25.20, Std reward: 3.31, total steps: 20004
# ----     Evaluation finished        ----
# -------- Episode 900 ended with reward 32.00 for model 0 --------
# Actor loss: -2.4930, Critic loss: 136.6580
# Total steps taken during training: 22780
# -------- Episode 1000 ended with reward 35.00 for model 0 --------
# Actor loss: -2.7996, Critic loss: 124.0987
# Total steps taken during training: 26024
# -------- Episode 1100 ended with reward 15.00 for model 0 --------
# Actor loss: 0.1478, Critic loss: 111.1745
# Total steps taken during training: 29450
# -------- Episode 1200 ended with reward 69.00 for model 0 --------
# Actor loss: -0.5040, Critic loss: 25.7547
# Total steps taken during training: 33349
# -------- Episode 1300 ended with reward 23.00 for model 0 --------
# Actor loss: -5.6377, Critic loss: 124.3165
# Total steps taken during training: 37488
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 162.70, Std reward: 136.94, total steps: 40002
# ----     Evaluation finished        ----
# -------- Episode 1400 ended with reward 28.00 for model 0 --------
# Actor loss: -3.2616, Critic loss: 28.2254
# Total steps taken during training: 42227
# -------- Episode 1500 ended with reward 115.00 for model 0 --------
# Actor loss: -2.3575, Critic loss: 133.9588
# Total steps taken during training: 47874
# -------- Episode 1600 ended with reward 144.00 for model 0 --------
# Actor loss: -3.3852, Critic loss: 480.3874
# Total steps taken during training: 57156
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 60000
# ----     Evaluation finished        ----
# -------- Episode 1700 ended with reward 140.00 for model 0 --------
# Actor loss: -1.0078, Critic loss: 143.8956
# Total steps taken during training: 70582
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 475.40, Std reward: 54.63, total steps: 80004
# ----     Evaluation finished        ----
# -------- Episode 1800 ended with reward 364.00 for model 0 --------
# Actor loss: -4.3599, Critic loss: 121.3837
# Total steps taken during training: 89276
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 449.40, Std reward: 45.00, total steps: 100002
# ----     Evaluation finished        ----
# -------- Episode 1900 ended with reward 206.00 for model 0 --------
# Actor loss: -0.8925, Critic loss: 149.2346
# Total steps taken during training: 114204
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 490.40, Std reward: 17.07, total steps: 120000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 487.70, Std reward: 36.90, total steps: 140004
# ----     Evaluation finished        ----
# -------- Episode 2000 ended with reward 500.00 for model 0 --------
# Actor loss: -0.0342, Critic loss: 0.0094
# Total steps taken during training: 154661
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 496.20, Std reward: 11.40, total steps: 160002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 180000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 200004
# ----     Evaluation finished        ----
# -------- Episode 2100 ended with reward 500.00 for model 0 --------
# Actor loss: -0.0103, Critic loss: 0.0003
# Total steps taken during training: 201926
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 220002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 240000
# ----     Evaluation finished        ----
# -------- Episode 2200 ended with reward 500.00 for model 0 --------
# Actor loss: -0.0003, Critic loss: 0.0003
# Total steps taken during training: 251238
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 260004
# ----     Evaluation finished        ----
# -------- Episode 2300 ended with reward 176.00 for model 0 --------
# Actor loss: 0.2512, Critic loss: 0.4107
# Total steps taken during training: 279776
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 165.60, Std reward: 20.29, total steps: 280002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 488.10, Std reward: 35.70, total steps: 300000
# ----     Evaluation finished        ----
# -------- Episode 2400 ended with reward 467.00 for model 0 --------
# Actor loss: -0.4831, Critic loss: 101.2632
# Total steps taken during training: 303026
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 320004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 340002
# ----     Evaluation finished        ----
# -------- Episode 2500 ended with reward 500.00 for model 0 --------
# Actor loss: 0.0007, Critic loss: 0.0000
# Total steps taken during training: 345497
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 360000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 380004
# ----     Evaluation finished        ----
# -------- Episode 2600 ended with reward 500.00 for model 0 --------
# Actor loss: -0.0000, Critic loss: 0.0000
# Total steps taken during training: 395743
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 400002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 420000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 440004
# ----     Evaluation finished        ----
# -------- Episode 2700 ended with reward 500.00 for model 0 --------
# Actor loss: -0.0001, Critic loss: 0.0000
# Total steps taken during training: 445826
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 460002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 480000
# ----     Evaluation finished        ----
# -------- Episode 2800 ended with reward 500.00 for model 0 --------
# Actor loss: -0.0000, Critic loss: 0.0000
# Total steps taken during training: 495497
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 500004
# ----     Evaluation finished        ----
# Reached total training budget of 500000 steps ----> Stopping training at episode 2808
# Experiment took 142.74s in total.
# -------- Episode 100 ended with reward 17.00 for model 1 --------
# Actor loss: -1.2673, Critic loss: 102.5765
# Total steps taken during training: 2124
# -------- Episode 200 ended with reward 25.00 for model 1 --------
# Actor loss: 1.2862, Critic loss: 12.5623
# Total steps taken during training: 4388
# -------- Episode 300 ended with reward 15.00 for model 1 --------
# Actor loss: -3.0872, Critic loss: 199.4641
# Total steps taken during training: 6781
# -------- Episode 400 ended with reward 20.00 for model 1 --------
# Actor loss: -3.1120, Critic loss: 204.2802
# Total steps taken during training: 9276
# -------- Episode 500 ended with reward 21.00 for model 1 --------
# Actor loss: -3.8096, Critic loss: 177.3203
# Total steps taken during training: 12250
# -------- Episode 600 ended with reward 34.00 for model 1 --------
# Actor loss: 0.1536, Critic loss: 71.8908
# Total steps taken during training: 15814
# -------- Episode 700 ended with reward 33.00 for model 1 --------
# Actor loss: -3.9436, Critic loss: 83.9247
# Total steps taken during training: 19640
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 164.80, Std reward: 50.52, total steps: 20004
# ----     Evaluation finished        ----
# -------- Episode 800 ended with reward 186.00 for model 1 --------
# Actor loss: -7.2223, Critic loss: 178.7940
# Total steps taken during training: 24619
# -------- Episode 900 ended with reward 164.00 for model 1 --------
# Actor loss: -17.9184, Critic loss: 849.9612
# Total steps taken during training: 30754
# -------- Episode 1000 ended with reward 22.00 for model 1 --------
# Actor loss: -0.3296, Critic loss: 154.7926
# Total steps taken during training: 38802
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 207.40, Std reward: 99.37, total steps: 40002
# ----     Evaluation finished        ----
# -------- Episode 1100 ended with reward 172.00 for model 1 --------
# Actor loss: -3.1286, Critic loss: 127.8941
# Total steps taken during training: 51616
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 416.40, Std reward: 69.82, total steps: 60000
# ----     Evaluation finished        ----
# -------- Episode 1200 ended with reward 180.00 for model 1 --------
# Actor loss: -2.5374, Critic loss: 338.4273
# Total steps taken during training: 67521
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 478.50, Std reward: 43.03, total steps: 80004
# ----     Evaluation finished        ----
# -------- Episode 1300 ended with reward 280.00 for model 1 --------
# Actor loss: -8.3969, Critic loss: 185.8359
# Total steps taken during training: 91729
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 489.40, Std reward: 31.80, total steps: 100002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 480.40, Std reward: 39.93, total steps: 120000
# ----     Evaluation finished        ----
# -------- Episode 1400 ended with reward 323.00 for model 1 --------
# Actor loss: -0.4393, Critic loss: 73.1312
# Total steps taken during training: 125533
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 140004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 160002
# ----     Evaluation finished        ----
# -------- Episode 1500 ended with reward 500.00 for model 1 --------
# Actor loss: 0.0509, Critic loss: 0.6766
# Total steps taken during training: 171706
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 413.00, Std reward: 57.14, total steps: 180000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 200004
# ----     Evaluation finished        ----
# -------- Episode 1600 ended with reward 500.00 for model 1 --------
# Actor loss: -0.0045, Critic loss: 0.0007
# Total steps taken during training: 219385
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 220002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 484.60, Std reward: 35.18, total steps: 240000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 260004
# ----     Evaluation finished        ----
# -------- Episode 1700 ended with reward 500.00 for model 1 --------
# Actor loss: -0.0089, Critic loss: 0.0001
# Total steps taken during training: 269408
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 280002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 300000
# ----     Evaluation finished        ----
# -------- Episode 1800 ended with reward 500.00 for model 1 --------
# Actor loss: -0.0007, Critic loss: 0.0000
# Total steps taken during training: 318814
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 489.90, Std reward: 20.64, total steps: 320004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 350.40, Std reward: 61.20, total steps: 340002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 360000
# ----     Evaluation finished        ----
# -------- Episode 1900 ended with reward 500.00 for model 1 --------
# Actor loss: 0.0005, Critic loss: 0.0000
# Total steps taken during training: 367558
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 380004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 400002
# ----     Evaluation finished        ----
# -------- Episode 2000 ended with reward 500.00 for model 1 --------
# Actor loss: -0.0004, Critic loss: 0.0000
# Total steps taken during training: 417587
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 420000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 440004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 460002
# ----     Evaluation finished        ----
# -------- Episode 2100 ended with reward 500.00 for model 1 --------
# Actor loss: 0.0002, Critic loss: 0.0000
# Total steps taken during training: 467223
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 480000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 500004
# ----     Evaluation finished        ----
# Reached total training budget of 500000 steps ----> Stopping training at episode 2165
# Experiment took 144.60s in total.
# -------- Episode 100 ended with reward 18.00 for model 2 --------
# Actor loss: -4.3479, Critic loss: 223.1896
# Total steps taken during training: 2593
# -------- Episode 200 ended with reward 11.00 for model 2 --------
# Actor loss: -2.8778, Critic loss: 214.5469
# Total steps taken during training: 4825
# -------- Episode 300 ended with reward 28.00 for model 2 --------
# Actor loss: -3.0376, Critic loss: 222.3765
# Total steps taken during training: 7011
# -------- Episode 400 ended with reward 17.00 for model 2 --------
# Actor loss: -2.0842, Critic loss: 175.0590
# Total steps taken during training: 9381
# -------- Episode 500 ended with reward 39.00 for model 2 --------
# Actor loss: -4.7282, Critic loss: 239.1338
# Total steps taken during training: 11926
# -------- Episode 600 ended with reward 22.00 for model 2 --------
# Actor loss: 0.2558, Critic loss: 8.5518
# Total steps taken during training: 14561
# -------- Episode 700 ended with reward 22.00 for model 2 --------
# Actor loss: -0.6161, Critic loss: 63.4199
# Total steps taken during training: 17988
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 57.60, Std reward: 33.85, total steps: 20004
# ----     Evaluation finished        ----
# -------- Episode 800 ended with reward 31.00 for model 2 --------
# Actor loss: 1.2724, Critic loss: 33.9417
# Total steps taken during training: 21801
# -------- Episode 900 ended with reward 59.00 for model 2 --------
# Actor loss: -0.9135, Critic loss: 62.9453
# Total steps taken during training: 26250
# -------- Episode 1000 ended with reward 51.00 for model 2 --------
# Actor loss: 0.4235, Critic loss: 59.5872
# Total steps taken during training: 31955
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 288.30, Std reward: 93.25, total steps: 40002
# ----     Evaluation finished        ----
# -------- Episode 1100 ended with reward 23.00 for model 2 --------
# Actor loss: 0.1913, Critic loss: 123.4972
# Total steps taken during training: 40594
# -------- Episode 1200 ended with reward 111.00 for model 2 --------
# Actor loss: -0.8413, Critic loss: 704.1912
# Total steps taken during training: 52394
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 408.70, Std reward: 90.14, total steps: 60000
# ----     Evaluation finished        ----
# -------- Episode 1300 ended with reward 268.00 for model 2 --------
# Actor loss: -7.2366, Critic loss: 347.7809
# Total steps taken during training: 70191
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 315.80, Std reward: 75.66, total steps: 80004
# ----     Evaluation finished        ----
# -------- Episode 1400 ended with reward 202.00 for model 2 --------
# Actor loss: -7.0337, Critic loss: 194.6637
# Total steps taken during training: 97475
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 389.10, Std reward: 80.30, total steps: 100002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 432.70, Std reward: 74.24, total steps: 120000
# ----     Evaluation finished        ----
# -------- Episode 1500 ended with reward 500.00 for model 2 --------
# Actor loss: 0.4764, Critic loss: 1.8566
# Total steps taken during training: 132302
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 364.00, Std reward: 36.54, total steps: 140004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 160002
# ----     Evaluation finished        ----
# -------- Episode 1600 ended with reward 470.00 for model 2 --------
# Actor loss: -0.0440, Critic loss: 743.2886
# Total steps taken during training: 171895
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 491.20, Std reward: 20.16, total steps: 180000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 494.60, Std reward: 12.06, total steps: 200004
# ----     Evaluation finished        ----
# -------- Episode 1700 ended with reward 500.00 for model 2 --------
# Actor loss: 0.0408, Critic loss: 0.3692
# Total steps taken during training: 205280
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 487.00, Std reward: 39.00, total steps: 220002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 433.50, Std reward: 61.57, total steps: 240000
# ----     Evaluation finished        ----
# -------- Episode 1800 ended with reward 500.00 for model 2 --------
# Actor loss: 0.0180, Critic loss: 0.3674
# Total steps taken during training: 249409
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 475.70, Std reward: 39.33, total steps: 260004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 280002
# ----     Evaluation finished        ----
# -------- Episode 1900 ended with reward 500.00 for model 2 --------
# Actor loss: -0.0041, Critic loss: 0.0107
# Total steps taken during training: 294357
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 489.20, Std reward: 32.40, total steps: 300000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 320004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 340002
# ----     Evaluation finished        ----
# -------- Episode 2000 ended with reward 500.00 for model 2 --------
# Actor loss: -0.0038, Critic loss: 0.0000
# Total steps taken during training: 342620
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 360000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 380004
# ----     Evaluation finished        ----
# -------- Episode 2100 ended with reward 266.00 for model 2 --------
# Actor loss: -3.7731, Critic loss: 1457.6089
# Total steps taken during training: 392027
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 400002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 420000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 440004
# ----     Evaluation finished        ----
# -------- Episode 2200 ended with reward 500.00 for model 2 --------
# Actor loss: 0.0297, Critic loss: 0.1372
# Total steps taken during training: 441304
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 495.30, Std reward: 14.10, total steps: 460002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 480000
# ----     Evaluation finished        ----
# -------- Episode 2300 ended with reward 500.00 for model 2 --------
# Actor loss: 0.0046, Critic loss: 0.0001
# Total steps taken during training: 491874
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 500004
# ----     Evaluation finished        ----
# Reached total training budget of 500000 steps ----> Stopping training at episode 2316
# Experiment took 143.08s in total.

# %% [markdown]
# ### training logging info
#
# - losses and rewards are every 1k step
# - evaluation rewards and value_trajectories are every 20k steps

# %%
len(all_critic_losses[0]),len(all_critic_losses[1]),len(all_critic_losses[2])
# Out:
# (500, 500, 500)

# %%
# Get stats 
min_critic_losses, max_critic_losses, avg_critic_losses = get_stats(all_critic_losses)
min_actor_losses, max_actor_losses, avg_actor_losses = get_stats(all_actor_losses)
min_episode_rewards, max_episode_rewards, avg_episode_rewards = get_stats(all_episode_rewards)

save_plots = True
folder_name = 'agent2'

# Plot stats 
plot_stats(save_plots, folder_name, min_critic_losses, max_critic_losses, avg_critic_losses, title='Critic Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_stats(save_plots, folder_name, min_actor_losses, max_actor_losses, avg_actor_losses, title='Actor Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_stats(save_plots, folder_name, min_episode_rewards, max_episode_rewards, avg_episode_rewards, title='Episode Rewards', ylabel='Reward', xlabel='Steps (every 1000 steps)')

# %%
# Plot smoothed stats 
window_size = 10

plot_smoothed_stats(save_plots, folder_name, min_critic_losses, max_critic_losses, avg_critic_losses, window_size, title='Critic Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_smoothed_stats(save_plots, folder_name, min_actor_losses, max_actor_losses, avg_actor_losses, window_size, title='Actor Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_smoothed_stats(save_plots, folder_name, min_episode_rewards, max_episode_rewards, avg_episode_rewards, window_size, title='Episode Rewards', ylabel='Reward', xlabel='Steps (every 1000 steps)')

# %%
# Get stats for evaluation rewards
min_eval_rew, max_eval_rew, avg_eval_rew = get_stats(all_evaluation_reward_means)

# Plot stats
plot_smoothed_stats(save_plots, folder_name, min_eval_rew, max_eval_rew, avg_eval_rew, window_size, title='Evaluation Episode Rewards',ylabel='Reward',xlabel='Steps (every 20k steps)')

# %%
plot_and_save_trajectories(save_plots, folder_name, all_evaluation_value_trajectories, x_range=[0, 500], y_range=[0, 150])

# %% [markdown]
# ### saving agents and data

# %%
folder_name = "data/data_agent2"

os.makedirs(folder_name, exist_ok=True)

# # Save all_* dictionaries
with open(folder_name+'/all_dicts.pkl', 'wb') as f:
    pickle.dump([all_critic_losses, all_actor_losses, all_episode_rewards, \
                 all_evaluation_reward_means, all_evaluation_reward_stds, all_evaluation_value_trajectories], f)

# Save agent3 dictionary
with open(folder_name+'/agent.pkl', 'wb') as f:
    pickle.dump(agent, f)

# # Save seed list used for training
with open(folder_name+'/seeds.pkl', 'wb') as f:
    pickle.dump(seeds, f)
