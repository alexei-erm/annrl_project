# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import collections
import pickle
import os


from training import *
from models import *
from A2C_agent import *
from helpers import *

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Load data and agents

# %%
# # Load all_* dictionaries
# with open('agent1_data/all_dicts.pkl', 'rb') as f:
#     all_critic_losses, all_actor_losses, all_episode_rewards, \
#         all_evaluation_reward_means, all_evaluation_reward_stds, all_evaluation_value_trajectories = pickle.load(f)

# # Load agent1 dictionary
# with open('agent1_data/agent1.pkl', 'rb') as f:
#     agent1 = pickle.load(f)

# %% [markdown]
# # 3.1 Agent 2: K-worker A2C version in CartPole
# ### K worker implementation (k=6)

# %%
# hyperparameters
stochastic_rewards = True
continuous = False
k=6
n=1
lr_actor=1e-5
lr_critic=1e-3
total_steps_budget = 500000
device = "cpu"
seeds = [77, 777, 7777]

agent, \
    all_critic_losses, all_actor_losses, all_episode_rewards, \
    all_evaluation_reward_means, all_evaluation_reward_stds, all_evaluation_value_trajectories \
        = training_loop(k, n, continuous, seeds, lr_actor, lr_critic, total_steps_budget, stochastic_rewards, device)
# Out:
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 56.90, Std reward: 13.13, total steps: 20004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 156.80, Std reward: 172.23, total steps: 40002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 333.30, Std reward: 117.00, total steps: 60000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 462.90, Std reward: 56.78, total steps: 80004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 495.80, Std reward: 12.60, total steps: 100002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 120000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 140004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 485.90, Std reward: 42.30, total steps: 160002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 180000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 200004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 220002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 240000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 453.10, Std reward: 39.75, total steps: 260004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 280002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 300000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 320004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 340002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 390.20, Std reward: 72.84, total steps: 360000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 440.40, Std reward: 52.69, total steps: 380004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 400002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 420000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 440004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 460002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 308.90, Std reward: 43.86, total steps: 480000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 461.50, Std reward: 36.09, total steps: 500004
# ----     Evaluation finished        ----
# Reached total training budget of 500000 steps ----> Stopping training at episode 0
# Experiment took 140.51s in total.
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 126.10, Std reward: 57.43, total steps: 20004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 426.00, Std reward: 80.75, total steps: 40002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 489.50, Std reward: 21.85, total steps: 60000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 442.90, Std reward: 79.70, total steps: 80004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 100002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 120000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 140004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 160002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 466.70, Std reward: 42.16, total steps: 180000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 200004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 220002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 240000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 260004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 280002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 300000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 320004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 340002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 360000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 471.70, Std reward: 52.40, total steps: 380004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 491.10, Std reward: 21.64, total steps: 400002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 420000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 440004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 392.20, Std reward: 68.61, total steps: 460002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 480000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 500004
# ----     Evaluation finished        ----
# Reached total training budget of 500000 steps ----> Stopping training at episode 0
# Experiment took 140.71s in total.
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 74.60, Std reward: 30.98, total steps: 20004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 201.30, Std reward: 46.60, total steps: 40002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 243.40, Std reward: 46.91, total steps: 60000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 446.50, Std reward: 60.86, total steps: 80004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 492.80, Std reward: 21.60, total steps: 100002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 457.20, Std reward: 48.03, total steps: 120000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 468.80, Std reward: 60.97, total steps: 140004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 495.00, Std reward: 15.00, total steps: 160002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 180000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 477.90, Std reward: 36.65, total steps: 200004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 220002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 240000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 260004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 493.20, Std reward: 20.40, total steps: 280002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 300000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 320004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 340002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 472.30, Std reward: 55.78, total steps: 360000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 493.30, Std reward: 20.10, total steps: 380004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 400002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 420000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 440004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 470.30, Std reward: 47.83, total steps: 460002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 500.00, Std reward: 0.00, total steps: 480000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 480.50, Std reward: 31.37, total steps: 500004
# ----     Evaluation finished        ----
# Reached total training budget of 500000 steps ----> Stopping training at episode 0
# Experiment took 140.47s in total.

# %% [markdown]
# ### training logging info
#
# - losses and rewards are every 1k step
# - evaluation rewards and value_trajectories are every 20k steps

# %%
len(all_critic_losses[0]),len(all_critic_losses[1]),len(all_critic_losses[2])
# Out:
# (500, 500, 500)

# %%
# Get stats 
min_critic_losses, max_critic_losses, avg_critic_losses = get_stats(all_critic_losses)
min_actor_losses, max_actor_losses, avg_actor_losses = get_stats(all_actor_losses)
min_episode_rewards, max_episode_rewards, avg_episode_rewards = get_stats(all_episode_rewards)

save_plots = True
folder_name = 'agent2'

# Plot stats 
plot_stats(save_plots, folder_name, min_critic_losses, max_critic_losses, avg_critic_losses, title='Critic Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_stats(save_plots, folder_name, min_actor_losses, max_actor_losses, avg_actor_losses, title='Actor Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_stats(save_plots, folder_name, min_episode_rewards, max_episode_rewards, avg_episode_rewards, title='Episode Rewards', ylabel='Reward', xlabel='Steps (every 1000 steps)')

# %%
# Plot smoothed stats 
window_size = 10

plot_smoothed_stats(save_plots, folder_name, min_critic_losses, max_critic_losses, avg_critic_losses, window_size, title='Critic Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_smoothed_stats(save_plots, folder_name, min_actor_losses, max_actor_losses, avg_actor_losses, window_size, title='Actor Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_smoothed_stats(save_plots, folder_name, min_episode_rewards, max_episode_rewards, avg_episode_rewards, window_size, title='Episode Rewards', ylabel='Reward', xlabel='Steps (every 1000 steps)')

# %%
# Get stats for evaluation rewards
min_eval_rew, max_eval_rew, avg_eval_rew = get_stats(all_evaluation_reward_means)

# Plot stats
plot_stats(save_plots, folder_name, min_eval_rew, max_eval_rew, avg_eval_rew, title='Evaluation Episode Rewards',ylabel='Reward',xlabel='Steps (every 20k steps)')

# %%
plot_and_save_trajectories(save_plots, folder_name, all_evaluation_value_trajectories, x_range=[0, 500], y_range=[0, 20])

# %% [markdown]
# ### saving agents and data

# %%
folder_name = "data/data_agent2"

os.makedirs(folder_name, exist_ok=True)

# # Save all_* dictionaries
with open(folder_name+'/all_dicts.pkl', 'wb') as f:
    pickle.dump([all_critic_losses, all_actor_losses, all_episode_rewards, \
                 all_evaluation_reward_means, all_evaluation_reward_stds, all_evaluation_value_trajectories], f)

# Save agent3 dictionary
with open(folder_name+'/agent.pkl', 'wb') as f:
    pickle.dump(agent, f)

# # Save seed list used for training
with open(folder_name+'/seeds.pkl', 'wb') as f:
    pickle.dump(seeds, f)
