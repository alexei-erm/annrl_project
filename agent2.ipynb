# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import collections
import pickle
import os


from headers.training import *
from models import *
from A2C_agent import *
from helpers import *

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Load data and agents

# %%
# # Load all_* dictionaries
# with open('agent1_data/all_dicts.pkl', 'rb') as f:
#     all_critic_losses, all_actor_losses, all_episode_rewards, \
#         all_evaluation_reward_means, all_evaluation_reward_stds, all_evaluation_value_trajectories = pickle.load(f)

# # Load agent1 dictionary
# with open('agent1_data/agent1.pkl', 'rb') as f:
#     agent1 = pickle.load(f)

# %% [markdown]
# # 3.1 Agent 2: K-worker A2C version in CartPole
# ### K worker implementation (k=6)

# %%
# hyperparameters
stochastic_rewards = False
continuous = False
k=6
n=1
lr_actor=1e-5
lr_critic=1e-3
total_steps_budget = 500000
device = "cpu"
seeds = [77, 777, 7777]

agent, \
    all_critic_losses, all_actor_losses, all_episode_rewards, \
    all_evaluation_reward_means, all_evaluation_reward_stds, all_evaluation_value_trajectories \
        = training_loop(k, n, continuous, seeds, lr_actor, lr_critic, total_steps_budget, stochastic_rewards, device)
# Out:
# -------- Episode 100 ended with reward 22.50 for model 0 --------
# Actor loss: -7.9976, Critic loss: 127.1394
# Total steps taken during training: 12039
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 37.50, Std reward: 8.42, total steps: 20000
# ----     Evaluation finished        ----
# -------- Episode 200 ended with reward 25.33 for model 0 --------
# Actor loss: -5.6262, Critic loss: 90.1348
# Total steps taken during training: 26469
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 50.30, Std reward: 13.18, total steps: 40003
# ----     Evaluation finished        ----
# -------- Episode 300 ended with reward 27.17 for model 0 --------
# Actor loss: -6.5458, Critic loss: 178.2656
# Total steps taken during training: 42354
# -------- Episode 400 ended with reward 38.50 for model 0 --------
# Actor loss: -4.7072, Critic loss: 92.2264
# Total steps taken during training: 59474
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 26.10, Std reward: 3.83, total steps: 60000
# ----     Evaluation finished        ----
# -------- Episode 500 ended with reward 32.17 for model 0 --------
# Actor loss: -19.3119, Critic loss: 219.9770
# Total steps taken during training: 76371
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 56.20, Std reward: 31.36, total steps: 80005
# ----     Evaluation finished        ----
# -------- Episode 600 ended with reward 30.67 for model 0 --------
# Actor loss: -7.7524, Critic loss: 53.1186
# Total steps taken during training: 96653
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 121.20, Std reward: 72.91, total steps: 100003
# ----     Evaluation finished        ----
# -------- Episode 700 ended with reward 45.17 for model 0 --------
# Actor loss: -9.8744, Critic loss: 179.6366
# Total steps taken during training: 117250
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 44.20, Std reward: 5.88, total steps: 120001
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 100.00, Std reward: 29.30, total steps: 140000
# ----     Evaluation finished        ----
# -------- Episode 800 ended with reward 40.67 for model 0 --------
# Actor loss: -19.2973, Critic loss: 574.9650
# Total steps taken during training: 141195
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 246.90, Std reward: 133.91, total steps: 160000
# ----     Evaluation finished        ----
# -------- Episode 900 ended with reward 77.50 for model 0 --------
# Actor loss: -2.8785, Critic loss: 179.0051
# Total steps taken during training: 172932
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 203.00, Std reward: 102.08, total steps: 180003
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 445.40, Std reward: 85.85, total steps: 200000
# ----     Evaluation finished        ----
# -------- Episode 1000 ended with reward 114.33 for model 0 --------
# Actor loss: -5.0639, Critic loss: 773.8678
# Total steps taken during training: 212692
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 269.80, Std reward: 80.18, total steps: 220002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 193.20, Std reward: 21.68, total steps: 240000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 330.60, Std reward: 119.64, total steps: 260001
# ----     Evaluation finished        ----
# -------- Episode 1100 ended with reward 108.67 for model 0 --------
# Actor loss: -8.9038, Critic loss: 1150.2051
# Total steps taken during training: 262729
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 224.30, Std reward: 47.44, total steps: 280000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 420.30, Std reward: 84.68, total steps: 300000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 398.70, Std reward: 95.31, total steps: 320001
# ----     Evaluation finished        ----
# -------- Episode 1200 ended with reward 99.83 for model 0 --------
# Actor loss: -28.1766, Critic loss: 1379.7012
# Total steps taken during training: 326160
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 398.00, Std reward: 104.03, total steps: 340001
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 445.40, Std reward: 90.61, total steps: 360001
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 500.00, Std reward: 0.00, total steps: 380004
# ----     Evaluation finished        ----
# -------- Episode 1300 ended with reward 169.00 for model 0 --------
# Actor loss: -41.8487, Critic loss: 2393.3069
# Total steps taken during training: 399720
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 500.00, Std reward: 0.00, total steps: 400002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 483.30, Std reward: 27.51, total steps: 420000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 422.20, Std reward: 79.40, total steps: 440001
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 500.00, Std reward: 0.00, total steps: 460000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 298.10, Std reward: 105.64, total steps: 480000
# ----     Evaluation finished        ----
# -------- Episode 1400 ended with reward 125.83 for model 0 --------
# Actor loss: -12.0296, Critic loss: 2929.9319
# Total steps taken during training: 486753
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 231.60, Std reward: 98.74, total steps: 500002
# ----     Evaluation finished        ----
# Reached total training budget of 500000 steps ----> Stopping training at episode 1416
# Experiment took -118.23s in total.
# -------- Episode 100 ended with reward 19.50 for model 1 --------
# Actor loss: -9.7202, Critic loss: 152.8835
# Total steps taken during training: 13535
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 72.20, Std reward: 20.21, total steps: 20004
# ----     Evaluation finished        ----
# -------- Episode 200 ended with reward 29.17 for model 1 --------
# Actor loss: -10.5437, Critic loss: 175.3476
# Total steps taken during training: 28623
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 40.70, Std reward: 7.14, total steps: 40002
# ----     Evaluation finished        ----
# -------- Episode 300 ended with reward 37.83 for model 1 --------
# Actor loss: -8.5596, Critic loss: 98.8542
# Total steps taken during training: 46436
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 77.90, Std reward: 24.55, total steps: 60003
# ----     Evaluation finished        ----
# -------- Episode 400 ended with reward 42.83 for model 1 --------
# Actor loss: -12.5538, Critic loss: 511.4298
# Total steps taken during training: 66656
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 167.70, Std reward: 100.40, total steps: 80000
# ----     Evaluation finished        ----
# -------- Episode 500 ended with reward 60.00 for model 1 --------
# Actor loss: -0.3408, Critic loss: 0.6716
# Total steps taken during training: 88576
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 177.90, Std reward: 83.05, total steps: 100002
# ----     Evaluation finished        ----
# -------- Episode 600 ended with reward 38.50 for model 1 --------
# Actor loss: -5.2095, Critic loss: 200.5564
# Total steps taken during training: 112144
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 275.90, Std reward: 123.07, total steps: 120003
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 70.90, Std reward: 9.20, total steps: 140001
# ----     Evaluation finished        ----
# -------- Episode 700 ended with reward 58.00 for model 1 --------
# Actor loss: -1.3601, Critic loss: 56.6310
# Total steps taken during training: 141254
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 328.40, Std reward: 149.36, total steps: 160000
# ----     Evaluation finished        ----
# -------- Episode 800 ended with reward 94.50 for model 1 --------
# Actor loss: -8.1543, Critic loss: 1450.4396
# Total steps taken during training: 178525
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 382.80, Std reward: 137.62, total steps: 180004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 318.90, Std reward: 124.51, total steps: 200003
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 500.00, Std reward: 0.00, total steps: 220005
# ----     Evaluation finished        ----
# -------- Episode 900 ended with reward 100.33 for model 1 --------
# Actor loss: -22.2993, Critic loss: 1010.8389
# Total steps taken during training: 223844
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 402.00, Std reward: 110.96, total steps: 240000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 167.30, Std reward: 10.81, total steps: 260000
# ----     Evaluation finished        ----
# -------- Episode 1000 ended with reward 58.17 for model 1 --------
# Actor loss: -6.7063, Critic loss: 958.0999
# Total steps taken during training: 275734
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 137.90, Std reward: 11.18, total steps: 280003
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 364.30, Std reward: 143.76, total steps: 300004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 449.50, Std reward: 66.87, total steps: 320004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 477.10, Std reward: 55.10, total steps: 340001
# ----     Evaluation finished        ----
# -------- Episode 1100 ended with reward 132.50 for model 1 --------
# Actor loss: -21.0337, Critic loss: 2298.2271
# Total steps taken during training: 340304
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 408.30, Std reward: 113.13, total steps: 360000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 346.20, Std reward: 109.18, total steps: 380001
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 259.70, Std reward: 26.26, total steps: 400004
# ----     Evaluation finished        ----
# -------- Episode 1200 ended with reward 96.33 for model 1 --------
# Actor loss: -79.0863, Critic loss: 2760.2712
# Total steps taken during training: 414446
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 410.90, Std reward: 82.33, total steps: 420001
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 419.20, Std reward: 74.27, total steps: 440000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 497.30, Std reward: 8.10, total steps: 460005
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 315.30, Std reward: 95.32, total steps: 480001
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 285.20, Std reward: 122.19, total steps: 500000
# ----     Evaluation finished        ----
# Reached total training budget of 500000 steps ----> Stopping training at episode 1299
# Experiment took -118.08s in total.
# -------- Episode 100 ended with reward 22.67 for model 2 --------
# Actor loss: -5.1601, Critic loss: 60.8560
# Total steps taken during training: 12880
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 15.40, Std reward: 2.33, total steps: 20002
# ----     Evaluation finished        ----
# -------- Episode 200 ended with reward 16.17 for model 2 --------
# Actor loss: -8.6549, Critic loss: 121.9340
# Total steps taken during training: 26553
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 19.10, Std reward: 1.70, total steps: 40004
# ----     Evaluation finished        ----
# -------- Episode 300 ended with reward 23.17 for model 2 --------
# Actor loss: -5.9848, Critic loss: 227.7959
# Total steps taken during training: 41719
# -------- Episode 400 ended with reward 29.00 for model 2 --------
# Actor loss: -8.8633, Critic loss: 424.4656
# Total steps taken during training: 58397
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 22.80, Std reward: 3.52, total steps: 60004
# ----     Evaluation finished        ----
# -------- Episode 500 ended with reward 35.00 for model 2 --------
# Actor loss: -12.2004, Critic loss: 226.4187
# Total steps taken during training: 76755
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 35.90, Std reward: 6.14, total steps: 80001
# ----     Evaluation finished        ----
# -------- Episode 600 ended with reward 37.00 for model 2 --------
# Actor loss: -29.6910, Critic loss: 495.4691
# Total steps taken during training: 99515
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 50.80, Std reward: 9.30, total steps: 100004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 94.20, Std reward: 18.68, total steps: 120002
# ----     Evaluation finished        ----
# -------- Episode 700 ended with reward 35.83 for model 2 --------
# Actor loss: -5.8559, Critic loss: 357.2285
# Total steps taken during training: 125154
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 136.00, Std reward: 34.42, total steps: 140001
# ----     Evaluation finished        ----
# -------- Episode 800 ended with reward 44.33 for model 2 --------
# Actor loss: -13.0185, Critic loss: 1163.0643
# Total steps taken during training: 158802
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 143.10, Std reward: 17.60, total steps: 160000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 292.30, Std reward: 56.71, total steps: 180004
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 192.40, Std reward: 27.58, total steps: 200005
# ----     Evaluation finished        ----
# -------- Episode 900 ended with reward 120.67 for model 2 --------
# Actor loss: -5.7663, Critic loss: 775.9525
# Total steps taken during training: 208351
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 170.90, Std reward: 13.11, total steps: 220000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 313.00, Std reward: 30.80, total steps: 240002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 223.30, Std reward: 22.29, total steps: 260004
# ----     Evaluation finished        ----
# -------- Episode 1000 ended with reward 107.67 for model 2 --------
# Actor loss: -86.0527, Critic loss: 1742.3802
# Total steps taken during training: 269425
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 285.40, Std reward: 34.68, total steps: 280003
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 305.70, Std reward: 27.48, total steps: 300005
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 262.30, Std reward: 70.69, total steps: 320000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 293.50, Std reward: 59.71, total steps: 340003
# ----     Evaluation finished        ----
# -------- Episode 1100 ended with reward 152.83 for model 2 --------
# Actor loss: -12.7307, Critic loss: 2379.7556
# Total steps taken during training: 354166
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 494.20, Std reward: 17.40, total steps: 360000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 230.70, Std reward: 36.95, total steps: 380003
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 440.00, Std reward: 57.77, total steps: 400003
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 495.20, Std reward: 10.97, total steps: 420003
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 492.60, Std reward: 22.20, total steps: 440001
# ----     Evaluation finished        ----
# -------- Episode 1200 ended with reward 184.67 for model 2 --------
# Actor loss: -20.3479, Critic loss: 3018.5278
# Total steps taken during training: 446437
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 500.00, Std reward: 0.00, total steps: 460003
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 459.60, Std reward: 66.47, total steps: 480002
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 292.70, Std reward: 64.23, total steps: 500005
# ----     Evaluation finished        ----
# Reached total training budget of 500000 steps ----> Stopping training at episode 1255
# Experiment took -116.23s in total.

# %% [markdown]
# ### training logging info
#
# - losses and rewards are every 1k step
# - evaluation rewards and value_trajectories are every 20k steps

# %%
len(all_critic_losses[0]),len(all_critic_losses[1]),len(all_critic_losses[2])
# Out:
# (500, 500, 500)

# %%
# Get stats 
min_critic_losses, max_critic_losses, avg_critic_losses = get_stats(all_critic_losses)
min_actor_losses, max_actor_losses, avg_actor_losses = get_stats(all_actor_losses)
min_episode_rewards, max_episode_rewards, avg_episode_rewards = get_stats(all_episode_rewards)

save_plots = True
folder_name = 'agent3'

# Plot stats 
plot_stats(save_plots, folder_name, min_critic_losses, max_critic_losses, avg_critic_losses, title='Critic Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_stats(save_plots, folder_name, min_actor_losses, max_actor_losses, avg_actor_losses, title='Actor Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_stats(save_plots, folder_name, min_episode_rewards, max_episode_rewards, avg_episode_rewards, title='Episode Rewards', ylabel='Reward', xlabel='Steps (every 1000 steps)')

# %%
# Plot smoothed stats 
window_size = 10

plot_smoothed_stats(save_plots, folder_name, min_critic_losses, max_critic_losses, avg_critic_losses, window_size, title='Critic Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_smoothed_stats(save_plots, folder_name, min_actor_losses, max_actor_losses, avg_actor_losses, window_size, title='Actor Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_smoothed_stats(save_plots, folder_name, min_episode_rewards, max_episode_rewards, avg_episode_rewards, window_size, title='Episode Rewards', ylabel='Reward', xlabel='Steps (every 1000 steps)')

# %%
# Get stats for evaluation rewards
min_eval_rew, max_eval_rew, avg_eval_rew = get_stats(all_evaluation_reward_means)

# Plot stats
plot_smoothed_stats(save_plots, folder_name, min_eval_rew, max_eval_rew, avg_eval_rew, window_size, title='Evaluation Episode Rewards',ylabel='Reward',xlabel='Steps (every 20k steps)')

# %%
plot_and_save_trajectories(save_plots, folder_name, all_evaluation_value_trajectories, x_range=[0, 500], y_range=[0, 150])

# %% [markdown]
# ### saving agents and data

# %%
folder_name = "data/data_agent2"

os.makedirs(folder_name, exist_ok=True)

# # Save all_* dictionaries
with open(folder_name+'/all_dicts.pkl', 'wb') as f:
    pickle.dump([all_critic_losses, all_actor_losses, all_episode_rewards, \
                 all_evaluation_reward_means, all_evaluation_reward_stds, all_evaluation_value_trajectories], f)

# Save agent3 dictionary
with open(folder_name+'/agent.pkl', 'wb') as f:
    pickle.dump(agent, f)

# # Save seed list used for training
with open(folder_name+'/seeds.pkl', 'wb') as f:
    pickle.dump(seeds, f)
