# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import collections
import pickle
import os


from training import *
from models import *
from A2C_agent import *
from helpers import *

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Load data and agents
#
# To produce all plots

# %%
# # Load all_* dictionaries
# agent_name = "chose the agent" # for example 'agent5'
# with open('data/'+agent_name+'_data/all_dicts.pkl', 'rb') as f:
#     all_critic_losses, all_actor_losses, all_episode_rewards, \
#         all_evaluation_reward_means, all_evaluation_reward_stds, all_evaluation_value_trajectories = pickle.load(f)

# # Load agent1 dictionary
# with open('data/'+agent_name+'_data/agent1.pkl', 'rb') as f:
#     agent1 = pickle.load(f)

# %% [markdown]
# # 4.2 Agent 5: Evaluating the CartPole agent in the new environment
# ### vanilla A2C (fully-online, n=1,k=1), continuous action space

# %%
# hyperparameters
stochastic_rewards = True
continuous = True
k=1
n=1
lr_actor=1e-5
lr_critic=1e-3
total_steps_budget = 500000
device = "cpu"
seeds = [734289, 324, 80435]

agent, \
all_critic_losses, all_actor_losses, all_episode_rewards, \
all_evaluation_reward_means, all_evaluation_reward_stds, all_evaluation_value_trajectories \
= training_loop(k, n, continuous, seeds, lr_actor, lr_critic, total_steps_budget, stochastic_rewards, device)
# Out:
# -------- Episode 100 ended with reward 6.00 for model 0 --------
# Actor loss: -1.3896, Critic loss: 1.0417
# Total steps taken during training: 910
# -------- Episode 200 ended with reward 8.00 for model 0 --------
# Actor loss: -0.5889, Critic loss: 0.4100
# Total steps taken during training: 1858
# -------- Episode 300 ended with reward 21.00 for model 0 --------
# Actor loss: -1.8735, Critic loss: 0.5587
# Total steps taken during training: 3011
# -------- Episode 400 ended with reward 9.00 for model 0 --------
# Actor loss: -1.3321, Critic loss: 1.1061
# Total steps taken during training: 4395
# -------- Episode 500 ended with reward 17.00 for model 0 --------
# Actor loss: -6.4697, Critic loss: 3.9641
# Total steps taken during training: 6014
# -------- Episode 600 ended with reward 9.00 for model 0 --------
# Actor loss: -0.2229, Critic loss: 0.0575
# Total steps taken during training: 8021
# -------- Episode 700 ended with reward 22.00 for model 0 --------
# Actor loss: -0.1943, Critic loss: 0.0222
# Total steps taken during training: 10043
# -------- Episode 800 ended with reward 15.00 for model 0 --------
# Actor loss: -0.2082, Critic loss: 0.0524
# Total steps taken during training: 12546
# -------- Episode 900 ended with reward 23.00 for model 0 --------
# Actor loss: -0.4176, Critic loss: 0.0541
# Total steps taken during training: 15337
# -------- Episode 1000 ended with reward 39.00 for model 0 --------
# Actor loss: -0.2741, Critic loss: 0.0143
# Total steps taken during training: 18533
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 89.50, Std reward: 37.45, total steps: 20000
# ----     Evaluation finished        ----
# -------- Episode 1100 ended with reward 17.00 for model 0 --------
# Actor loss: -3.0926, Critic loss: 3.0335
# Total steps taken during training: 22677
# -------- Episode 1200 ended with reward 148.00 for model 0 --------
# Actor loss: -0.4794, Critic loss: 0.2641
# Total steps taken during training: 28208
# -------- Episode 1300 ended with reward 93.00 for model 0 --------
# Actor loss: -3.1386, Critic loss: 6.6408
# Total steps taken during training: 35239
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 85.60, Std reward: 2.50, total steps: 40000
# ----     Evaluation finished        ----
# -------- Episode 1400 ended with reward 117.00 for model 0 --------
# Actor loss: -2.4183, Critic loss: 5.1647
# Total steps taken during training: 44022
# -------- Episode 1500 ended with reward 143.00 for model 0 --------
# Actor loss: -3.6612, Critic loss: 9.4002
# Total steps taken during training: 54677
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 270.90, Std reward: 10.85, total steps: 60000
# ----     Evaluation finished        ----
# -------- Episode 1600 ended with reward 249.00 for model 0 --------
# Actor loss: -6.4783, Critic loss: 22.4890
# Total steps taken during training: 66823
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 80000
# ----     Evaluation finished        ----
# -------- Episode 1700 ended with reward 100.00 for model 0 --------
# Actor loss: 0.1483, Critic loss: 0.0060
# Total steps taken during training: 80465
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 100000
# ----     Evaluation finished        ----
# -------- Episode 1800 ended with reward 851.00 for model 0 --------
# Actor loss: -14.6591, Critic loss: 51.2920
# Total steps taken during training: 102025
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 120000
# ----     Evaluation finished        ----
# -------- Episode 1900 ended with reward 1000.00 for model 0 --------
# Actor loss: -0.0342, Critic loss: 0.0016
# Total steps taken during training: 139918
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 140000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 160000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 180000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 200000
# ----     Evaluation finished        ----
# -------- Episode 2000 ended with reward 409.00 for model 0 --------
# Actor loss: -0.9379, Critic loss: 0.8577
# Total steps taken during training: 210063
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 220000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 240000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 260000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 280000
# ----     Evaluation finished        ----
# -------- Episode 2100 ended with reward 157.00 for model 0 --------
# Actor loss: -24.9124, Critic loss: 75.0968
# Total steps taken during training: 297258
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 300000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 320000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 340000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 360000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 380000
# ----     Evaluation finished        ----
# -------- Episode 2200 ended with reward 1000.00 for model 0 --------
# Actor loss: -0.4206, Critic loss: 0.0271
# Total steps taken during training: 382791
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 400000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 420000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 440000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 460000
# ----     Evaluation finished        ----
# -------- Episode 2300 ended with reward 1000.00 for model 0 --------
# Actor loss: 0.7316, Critic loss: 0.8534
# Total steps taken during training: 476011
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 480000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 500000
# ----     Evaluation finished        ----
# Reached total training budget of 500000 steps ----> Stopping training at episode 2323
# Experiment took 261.01s in total.
# -------- Episode 100 ended with reward 4.00 for model 1 --------
# Actor loss: 0.4743, Critic loss: 0.2546
# Total steps taken during training: 823
# -------- Episode 200 ended with reward 9.00 for model 1 --------
# Actor loss: -0.8322, Critic loss: 0.6110
# Total steps taken during training: 1672
# -------- Episode 300 ended with reward 7.00 for model 1 --------
# Actor loss: -0.3491, Critic loss: 0.1167
# Total steps taken during training: 2567
# -------- Episode 400 ended with reward 6.00 for model 1 --------
# Actor loss: -0.9432, Critic loss: 0.4811
# Total steps taken during training: 3597
# -------- Episode 500 ended with reward 23.00 for model 1 --------
# Actor loss: -0.6827, Critic loss: 0.5459
# Total steps taken during training: 4746
# -------- Episode 600 ended with reward 6.00 for model 1 --------
# Actor loss: -0.9787, Critic loss: 1.0435
# Total steps taken during training: 6178
# -------- Episode 700 ended with reward 33.00 for model 1 --------
# Actor loss: -0.4355, Critic loss: 0.1254
# Total steps taken during training: 7872
# -------- Episode 800 ended with reward 9.00 for model 1 --------
# Actor loss: -0.2948, Critic loss: 0.0353
# Total steps taken during training: 9786
# -------- Episode 900 ended with reward 19.00 for model 1 --------
# Actor loss: -1.2059, Critic loss: 0.6302
# Total steps taken during training: 12389
# -------- Episode 1000 ended with reward 20.00 for model 1 --------
# Actor loss: -0.3326, Critic loss: 0.0487
# Total steps taken during training: 14950
# -------- Episode 1100 ended with reward 68.00 for model 1 --------
# Actor loss: -3.9185, Critic loss: 3.7018
# Total steps taken during training: 18395
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 88.20, Std reward: 6.03, total steps: 20000
# ----     Evaluation finished        ----
# -------- Episode 1200 ended with reward 22.00 for model 1 --------
# Actor loss: 0.9082, Critic loss: 0.2352
# Total steps taken during training: 22546
# -------- Episode 1300 ended with reward 47.00 for model 1 --------
# Actor loss: -1.1607, Critic loss: 1.2329
# Total steps taken during training: 27833
# -------- Episode 1400 ended with reward 67.00 for model 1 --------
# Actor loss: -0.2065, Critic loss: 0.0407
# Total steps taken during training: 34692
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 158.40, Std reward: 7.20, total steps: 40000
# ----     Evaluation finished        ----
# -------- Episode 1500 ended with reward 83.00 for model 1 --------
# Actor loss: -1.5276, Critic loss: 2.0282
# Total steps taken during training: 42238
# -------- Episode 1600 ended with reward 253.00 for model 1 --------
# Actor loss: -1.1159, Critic loss: 0.7618
# Total steps taken during training: 51173
# -------- Episode 1700 ended with reward 102.00 for model 1 --------
# Actor loss: -0.7704, Critic loss: 0.7696
# Total steps taken during training: 59881
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 201.40, Std reward: 14.43, total steps: 60000
# ----     Evaluation finished        ----
# -------- Episode 1800 ended with reward 130.00 for model 1 --------
# Actor loss: -1.4649, Critic loss: 2.2890
# Total steps taken during training: 69074
# -------- Episode 1900 ended with reward 56.00 for model 1 --------
# Actor loss: 0.1582, Critic loss: 0.0234
# Total steps taken during training: 79199
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 192.70, Std reward: 8.38, total steps: 80000
# ----     Evaluation finished        ----
# -------- Episode 2000 ended with reward 125.00 for model 1 --------
# Actor loss: -2.7199, Critic loss: 0.8751
# Total steps taken during training: 90037
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 254.90, Std reward: 6.62, total steps: 100000
# ----     Evaluation finished        ----
# -------- Episode 2100 ended with reward 102.00 for model 1 --------
# Actor loss: -0.6763, Critic loss: 0.3015
# Total steps taken during training: 102448
# -------- Episode 2200 ended with reward 221.00 for model 1 --------
# Actor loss: -4.5799, Critic loss: 30.0664
# Total steps taken during training: 119010
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 414.70, Std reward: 10.70, total steps: 120000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 371.70, Std reward: 3.69, total steps: 140000
# ----     Evaluation finished        ----
# -------- Episode 2300 ended with reward 381.00 for model 1 --------
# Actor loss: -2.6902, Critic loss: 10.1153
# Total steps taken during training: 140587
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 160000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 180000
# ----     Evaluation finished        ----
# -------- Episode 2400 ended with reward 1000.00 for model 1 --------
# Actor loss: -0.0420, Critic loss: 0.0020
# Total steps taken during training: 188006
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 200000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 220000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 240000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 260000
# ----     Evaluation finished        ----
# -------- Episode 2500 ended with reward 785.00 for model 1 --------
# Actor loss: -9.8893, Critic loss: 60.1597
# Total steps taken during training: 268757
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 280000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 300000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 320000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 340000
# ----     Evaluation finished        ----
# -------- Episode 2600 ended with reward 540.00 for model 1 --------
# Actor loss: 0.4187, Critic loss: 0.2910
# Total steps taken during training: 356786
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 360000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 380000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 400000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 420000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 440000
# ----     Evaluation finished        ----
# -------- Episode 2700 ended with reward 1000.00 for model 1 --------
# Actor loss: -0.1142, Critic loss: 0.0139
# Total steps taken during training: 453461
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 460000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 480000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 500000
# ----     Evaluation finished        ----
# Reached total training budget of 500000 steps ----> Stopping training at episode 2746
# Experiment took 264.02s in total.
# -------- Episode 100 ended with reward 8.00 for model 2 --------
# Actor loss: 0.0288, Critic loss: 0.0008
# Total steps taken during training: 852
# -------- Episode 200 ended with reward 6.00 for model 2 --------
# Actor loss: -0.2268, Critic loss: 0.0339
# Total steps taken during training: 1741
# -------- Episode 300 ended with reward 13.00 for model 2 --------
# Actor loss: -0.5247, Critic loss: 0.3259
# Total steps taken during training: 2698
# -------- Episode 400 ended with reward 9.00 for model 2 --------
# Actor loss: -1.5084, Critic loss: 1.2597
# Total steps taken during training: 3808
# -------- Episode 500 ended with reward 11.00 for model 2 --------
# Actor loss: 0.2535, Critic loss: 0.0509
# Total steps taken during training: 5181
# -------- Episode 600 ended with reward 24.00 for model 2 --------
# Actor loss: -0.8670, Critic loss: 0.5605
# Total steps taken during training: 6942
# -------- Episode 700 ended with reward 9.00 for model 2 --------
# Actor loss: -0.5391, Critic loss: 0.1473
# Total steps taken during training: 8911
# -------- Episode 800 ended with reward 17.00 for model 2 --------
# Actor loss: -0.4167, Critic loss: 0.2098
# Total steps taken during training: 11428
# -------- Episode 900 ended with reward 99.00 for model 2 --------
# Actor loss: -1.8307, Critic loss: 3.2377
# Total steps taken during training: 14359
# -------- Episode 1000 ended with reward 42.00 for model 2 --------
# Actor loss: -3.0093, Critic loss: 5.9107
# Total steps taken during training: 18290
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 86.70, Std reward: 6.26, total steps: 20000
# ----     Evaluation finished        ----
# -------- Episode 1100 ended with reward 78.00 for model 2 --------
# Actor loss: -1.3993, Critic loss: 0.5956
# Total steps taken during training: 23869
# -------- Episode 1200 ended with reward 144.00 for model 2 --------
# Actor loss: -2.3374, Critic loss: 6.9538
# Total steps taken during training: 31256
# -------- Episode 1300 ended with reward 97.00 for model 2 --------
# Actor loss: -1.0204, Critic loss: 0.7792
# Total steps taken during training: 39518
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 216.00, Std reward: 7.33, total steps: 40000
# ----     Evaluation finished        ----
# -------- Episode 1400 ended with reward 59.00 for model 2 --------
# Actor loss: -6.4395, Critic loss: 14.2214
# Total steps taken during training: 49612
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 417.30, Std reward: 38.10, total steps: 60000
# ----     Evaluation finished        ----
# -------- Episode 1500 ended with reward 326.00 for model 2 --------
# Actor loss: -1.6876, Critic loss: 0.6578
# Total steps taken during training: 62966
# -------- Episode 1600 ended with reward 101.00 for model 2 --------
# Actor loss: -6.5573, Critic loss: 8.9708
# Total steps taken during training: 76842
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 80000
# ----     Evaluation finished        ----
# -------- Episode 1700 ended with reward 58.00 for model 2 --------
# Actor loss: -6.0064, Critic loss: 39.0982
# Total steps taken during training: 95354
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 100000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 120000
# ----     Evaluation finished        ----
# -------- Episode 1800 ended with reward 445.00 for model 2 --------
# Actor loss: -7.0350, Critic loss: 67.4922
# Total steps taken during training: 121968
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 140000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 160000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 180000
# ----     Evaluation finished        ----
# -------- Episode 1900 ended with reward 1000.00 for model 2 --------
# Actor loss: 0.7465, Critic loss: 0.7456
# Total steps taken during training: 183468
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 200000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 220000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 240000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 260000
# ----     Evaluation finished        ----
# -------- Episode 2000 ended with reward 1000.00 for model 2 --------
# Actor loss: -0.0636, Critic loss: 0.0063
# Total steps taken during training: 263975
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 280000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 300000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 320000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 340000
# ----     Evaluation finished        ----
# -------- Episode 2100 ended with reward 1000.00 for model 2 --------
# Actor loss: -0.3417, Critic loss: 0.0124
# Total steps taken during training: 354069
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 360000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 380000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 400000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 420000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 440000
# ----     Evaluation finished        ----
# -------- Episode 2200 ended with reward 1000.00 for model 2 --------
# Actor loss: -0.0378, Critic loss: 0.0016
# Total steps taken during training: 448167
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 460000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 480000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
#  Mean reward: 1000.00, Std reward: 0.00, total steps: 500000
# ----     Evaluation finished        ----
# Reached total training budget of 500000 steps ----> Stopping training at episode 2254
# Experiment took 262.57s in total.

# %% [markdown]
# ### training logging info
#
# - losses and rewards are every 1k step
# - evaluation rewards and value_trajectories are every 20k steps

# %%
# Get stats 
min_critic_losses, max_critic_losses, avg_critic_losses = get_stats(all_critic_losses)
min_actor_losses, max_actor_losses, avg_actor_losses = get_stats(all_actor_losses)
min_episode_rewards, max_episode_rewards, avg_episode_rewards = get_stats(all_episode_rewards)

save_plots = True
folder_name = 'agent5'

# Plot stats 
plot_stats(save_plots, folder_name, min_critic_losses, max_critic_losses, avg_critic_losses, title='Critic Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_stats(save_plots, folder_name, min_actor_losses, max_actor_losses, avg_actor_losses, title='Actor Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_stats(save_plots, folder_name, min_episode_rewards, max_episode_rewards, avg_episode_rewards, title='Episode Rewards', ylabel='Reward', xlabel='Steps (every 1000 steps)')

# %%
# Plot smoothed stats 
window_size = 10

plot_smoothed_stats(save_plots, folder_name, min_critic_losses, max_critic_losses, avg_critic_losses, window_size, title='Smoothed Critic Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_smoothed_stats(save_plots, folder_name, min_actor_losses, max_actor_losses, avg_actor_losses, window_size, title='Smoothed Actor Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_smoothed_stats(save_plots, folder_name, min_episode_rewards, max_episode_rewards, avg_episode_rewards, window_size, title='Smoothed Episode Rewards', ylabel='Reward', xlabel='Steps (every 1000 steps)')

# %%
# Get stats for evaluation rewards
min_eval_rew, max_eval_rew, avg_eval_rew = get_stats(all_evaluation_reward_means)

# Plot stats
plot_smoothed_stats(save_plots, folder_name, min_eval_rew, max_eval_rew, avg_eval_rew, window_size, title='Evaluation Episode Rewards',ylabel='Reward',xlabel='Steps (every 20k steps)')

# %%
plot_and_save_trajectories(save_plots, folder_name, all_evaluation_value_trajectories, x_range=[0, 500], y_range=[0, 150])

# %% [markdown]
# ### saving agents and data

# %%
folder_name = "data/data_agent5"

os.makedirs(folder_name, exist_ok=True)

# # Save all_* dictionaries
with open(folder_name+'/all_dicts.pkl', 'wb') as f:
    pickle.dump([all_critic_losses, all_actor_losses, all_episode_rewards, \
                 all_evaluation_reward_means, all_evaluation_reward_stds, all_evaluation_value_trajectories], f)

# Save agent3 dictionary
with open(folder_name+'/agent.pkl', 'wb') as f:
    pickle.dump(agent, f)

# # Save seed list used for training
with open(folder_name+'/seeds.pkl', 'wb') as f:
    pickle.dump(seeds, f)
