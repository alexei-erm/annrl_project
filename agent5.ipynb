# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import collections
import pickle
import os


from training import *
from models import *
from A2C_agent import *
from helpers import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Load data and agents

# %%
# # Load all_* dictionaries
# with open('agent1_data/all_dicts.pkl', 'rb') as f:
#     all_critic_losses, all_actor_losses, all_episode_rewards, \
#         all_evaluation_reward_means, all_evaluation_reward_stds, all_evaluation_value_trajectories = pickle.load(f)

# # Load agent1 dictionary
# with open('agent1_data/agent1.pkl', 'rb') as f:
#     agent1 = pickle.load(f)

# %% [markdown]
# # 4.2 Agent 5: Evaluating the CartPole agent in the new environment
# ### vanilla A2C (fully-online)

# %%
# hyperparameters
stochastic_rewards = False
continuous = True
k=1
n=1
total_steps_budget = 500000
device = "cpu"
seeds = [77777, 33, 333]

agent, \
all_critic_losses, all_actor_losses, all_episode_rewards, \
all_evaluation_reward_means, all_evaluation_reward_stds, all_evaluation_value_trajectories \
= training_loop(k, n, continuous, seeds, lr_actor=1e-5, lr_critic=1e-3, total_steps_budget=500000, stochastic_rewards=False, device="cpu")
# Out:
# -------- Episode 100 ended with reward 8.0 for model 0 --------
# Actor loss: -5.0666, Critic loss: 13.6012
# Total steps taken during training: 881
# -------- Episode 200 ended with reward 15.0 for model 0 --------
# Actor loss: -2.6248, Critic loss: 1.1475
# Total steps taken during training: 1815
# -------- Episode 300 ended with reward 14.0 for model 0 --------
# Actor loss: 0.0205, Critic loss: 0.0003
# Total steps taken during training: 2653
# -------- Episode 400 ended with reward 21.0 for model 0 --------
# Actor loss: -1.3107, Critic loss: 0.7452
# Total steps taken during training: 3491
# -------- Episode 500 ended with reward 6.0 for model 0 --------
# Actor loss: -0.1322, Critic loss: 0.0174
# Total steps taken during training: 4377
# -------- Episode 600 ended with reward 18.0 for model 0 --------
# Actor loss: -2.3573, Critic loss: 3.7525
# Total steps taken during training: 5139
# -------- Episode 700 ended with reward 5.0 for model 0 --------
# Actor loss: -0.9363, Critic loss: 0.6751
# Total steps taken during training: 5907
# -------- Episode 800 ended with reward 9.0 for model 0 --------
# Actor loss: -0.0057, Critic loss: 0.0000
# Total steps taken during training: 6711
# -------- Episode 900 ended with reward 4.0 for model 0 --------
# Actor loss: 0.0969, Critic loss: 0.0092
# Total steps taken during training: 7566
# -------- Episode 1000 ended with reward 4.0 for model 0 --------
# Actor loss: -0.0425, Critic loss: 0.0018
# Total steps taken during training: 8462
# -------- Episode 1100 ended with reward 7.0 for model 0 --------
# Actor loss: -2.0675, Critic loss: 0.8842
# Total steps taken during training: 9222
# -------- Episode 1200 ended with reward 6.0 for model 0 --------
# Actor loss: 0.3949, Critic loss: 0.1190
# Total steps taken during training: 10051
# -------- Episode 1300 ended with reward 5.0 for model 0 --------
# Actor loss: 0.2853, Critic loss: 0.0547
# Total steps taken during training: 10873
# -------- Episode 1400 ended with reward 13.0 for model 0 --------
# Actor loss: 0.2921, Critic loss: 0.0940
# Total steps taken during training: 11719
# -------- Episode 1500 ended with reward 15.0 for model 0 --------
# Actor loss: -1.3506, Critic loss: 2.1241
# Total steps taken during training: 12559
# -------- Episode 1600 ended with reward 7.0 for model 0 --------
# Actor loss: -0.9101, Critic loss: 0.5328
# Total steps taken during training: 13414
# -------- Episode 1700 ended with reward 7.0 for model 0 --------
# Actor loss: -0.8140, Critic loss: 0.1873
# Total steps taken during training: 14283
# -------- Episode 1800 ended with reward 8.0 for model 0 --------
# Actor loss: -5.8595, Critic loss: 3.0747
# Total steps taken during training: 15193
# -------- Episode 1900 ended with reward 4.0 for model 0 --------
# Actor loss: -5.0233, Critic loss: 6.9944
# Total steps taken during training: 16097
# -------- Episode 2000 ended with reward 4.0 for model 0 --------
# Actor loss: -1.3605, Critic loss: 0.3515
# Total steps taken during training: 16999
# -------- Episode 2100 ended with reward 8.0 for model 0 --------
# Actor loss: -0.3186, Critic loss: 0.1198
# Total steps taken during training: 17822
# -------- Episode 2200 ended with reward 5.0 for model 0 --------
# Actor loss: -0.1926, Critic loss: 0.0197
# Total steps taken during training: 18707
# -------- Episode 2300 ended with reward 8.0 for model 0 --------
# Actor loss: -2.3662, Critic loss: 6.1504
# Total steps taken during training: 19547
# -------- Episode 2400 ended with reward 9.0 for model 0 --------
# Actor loss: -0.2557, Critic loss: 0.0764
# Total steps taken during training: 20393
# -------- Episode 2500 ended with reward 16.0 for model 0 --------
# Actor loss: -0.4523, Critic loss: 0.2414
# Total steps taken during training: 21247
# -------- Episode 2600 ended with reward 6.0 for model 0 --------
# Actor loss: -0.5758, Critic loss: 0.3901
# Total steps taken during training: 22101
# -------- Episode 2700 ended with reward 7.0 for model 0 --------
# Actor loss: -1.0517, Critic loss: 0.6268
# Total steps taken during training: 22973
# -------- Episode 2800 ended with reward 7.0 for model 0 --------
# Actor loss: -0.4501, Critic loss: 0.1142
# Total steps taken during training: 23801
# -------- Episode 2900 ended with reward 11.0 for model 0 --------
# Actor loss: -1.2201, Critic loss: 0.2948
# Total steps taken during training: 24566
# -------- Episode 3000 ended with reward 4.0 for model 0 --------
# Actor loss: 0.4237, Critic loss: 0.1894
# Total steps taken during training: 25433
# -------- Episode 3100 ended with reward 5.0 for model 0 --------
# Actor loss: 0.0224, Critic loss: 0.0005
# Total steps taken during training: 26261
# -------- Episode 3200 ended with reward 8.0 for model 0 --------
# Actor loss: -1.3145, Critic loss: 0.5558
# Total steps taken during training: 27123
# -------- Episode 3300 ended with reward 4.0 for model 0 --------
# Actor loss: -3.8724, Critic loss: 1.0152
# Total steps taken during training: 27941
# -------- Episode 3400 ended with reward 6.0 for model 0 --------
# Actor loss: -0.7839, Critic loss: 0.4827
# Total steps taken during training: 28732
# -------- Episode 3500 ended with reward 9.0 for model 0 --------
# Actor loss: -0.8611, Critic loss: 0.8504
# Total steps taken during training: 29629
# -------- Episode 3600 ended with reward 4.0 for model 0 --------
# Actor loss: -0.6464, Critic loss: 0.0736
# Total steps taken during training: 30564
# -------- Episode 3700 ended with reward 6.0 for model 0 --------
# Actor loss: -2.7509, Critic loss: 1.1866
# Total steps taken during training: 31476
# -------- Episode 3800 ended with reward 7.0 for model 0 --------
# Actor loss: -0.1934, Critic loss: 0.0129
# Total steps taken during training: 32260
# -------- Episode 3900 ended with reward 4.0 for model 0 --------
# Actor loss: -0.3539, Critic loss: 0.1017
# Total steps taken during training: 33052
# -------- Episode 4000 ended with reward 8.0 for model 0 --------
# Actor loss: -0.0131, Critic loss: 0.0002
# Total steps taken during training: 33865
# -------- Episode 4100 ended with reward 7.0 for model 0 --------
# Actor loss: -2.3853, Critic loss: 2.1297
# Total steps taken during training: 34813
# -------- Episode 4200 ended with reward 7.0 for model 0 --------
# Actor loss: 0.3060, Critic loss: 0.0721
# Total steps taken during training: 35747
# -------- Episode 4300 ended with reward 7.0 for model 0 --------
# Actor loss: -1.4062, Critic loss: 0.7823
# Total steps taken during training: 36572
# -------- Episode 4400 ended with reward 10.0 for model 0 --------
# Actor loss: -5.6650, Critic loss: 5.8855
# Total steps taken during training: 37445
# -------- Episode 4500 ended with reward 4.0 for model 0 --------
# Actor loss: -0.3585, Critic loss: 0.0768
# Total steps taken during training: 38318
# -------- Episode 4600 ended with reward 13.0 for model 0 --------
# Actor loss: -2.0626, Critic loss: 4.3842
# Total steps taken during training: 39199
# -------- Episode 4700 ended with reward 6.0 for model 0 --------
# Actor loss: 0.4019, Critic loss: 0.0522
# Total steps taken during training: 40053
# -------- Episode 4800 ended with reward 4.0 for model 0 --------
# Actor loss: -0.8805, Critic loss: 0.9152
# Total steps taken during training: 40816
# -------- Episode 4900 ended with reward 8.0 for model 0 --------
# Actor loss: -1.6703, Critic loss: 3.1853
# Total steps taken during training: 41752
# -------- Episode 5000 ended with reward 10.0 for model 0 --------
# Actor loss: -1.0011, Critic loss: 0.7716
# Total steps taken during training: 42661
# -------- Episode 5100 ended with reward 6.0 for model 0 --------
# Actor loss: -7.1352, Critic loss: 7.0898
# Total steps taken during training: 43487
# -------- Episode 5200 ended with reward 8.0 for model 0 --------
# Actor loss: -1.8083, Critic loss: 3.8959
# Total steps taken during training: 44315
# -------- Episode 5300 ended with reward 4.0 for model 0 --------
# Actor loss: -0.4324, Critic loss: 0.0940
# Total steps taken during training: 45253
# -------- Episode 5400 ended with reward 6.0 for model 0 --------
# Actor loss: -2.3861, Critic loss: 6.6651
# Total steps taken during training: 46082
# -------- Episode 5500 ended with reward 8.0 for model 0 --------
# Actor loss: -0.7821, Critic loss: 0.4823
# Total steps taken during training: 46928
# -------- Episode 5600 ended with reward 8.0 for model 0 --------
# Actor loss: 0.4679, Critic loss: 0.0698
# Total steps taken during training: 47842
# -------- Episode 5700 ended with reward 5.0 for model 0 --------
# Actor loss: -0.8395, Critic loss: 0.2252
# Total steps taken during training: 48656
# -------- Episode 5800 ended with reward 21.0 for model 0 --------
# Actor loss: -0.9702, Critic loss: 0.5060
# Total steps taken during training: 49506
# -------- Episode 5900 ended with reward 8.0 for model 0 --------
# Actor loss: 0.3641, Critic loss: 0.0563
# Total steps taken during training: 50374
# -------- Episode 6000 ended with reward 5.0 for model 0 --------
# Actor loss: -1.9447, Critic loss: 3.8423
# Total steps taken during training: 51150
# -------- Episode 6100 ended with reward 15.0 for model 0 --------
# Actor loss: -0.7784, Critic loss: 0.7004
# Total steps taken during training: 52064
# -------- Episode 6200 ended with reward 13.0 for model 0 --------
# Actor loss: -1.4615, Critic loss: 2.2785
# Total steps taken during training: 52870
# -------- Episode 6300 ended with reward 7.0 for model 0 --------
# Actor loss: -0.5940, Critic loss: 0.3532
# Total steps taken during training: 53721
# -------- Episode 6400 ended with reward 11.0 for model 0 --------
# Actor loss: -0.6625, Critic loss: 0.5010
# Total steps taken during training: 54571
# -------- Episode 6500 ended with reward 15.0 for model 0 --------
# Actor loss: -0.7526, Critic loss: 0.1112
# Total steps taken during training: 55410
# -------- Episode 6600 ended with reward 3.0 for model 0 --------
# Actor loss: -1.1416, Critic loss: 1.5443
# Total steps taken during training: 56246
# -------- Episode 6700 ended with reward 15.0 for model 0 --------
# Actor loss: -2.8193, Critic loss: 4.8718
# Total steps taken during training: 57302
# -------- Episode 6800 ended with reward 19.0 for model 0 --------
# Actor loss: -1.0785, Critic loss: 1.1284
# Total steps taken during training: 58010
# -------- Episode 6900 ended with reward 12.0 for model 0 --------
# Actor loss: -0.8914, Critic loss: 0.5135
# Total steps taken during training: 58884
# -------- Episode 7000 ended with reward 6.0 for model 0 --------
# Actor loss: -0.5425, Critic loss: 0.0853
# Total steps taken during training: 59740
# -------- Episode 7100 ended with reward 7.0 for model 0 --------
# Actor loss: -0.9592, Critic loss: 1.0744
# Total steps taken during training: 60579
# -------- Episode 7200 ended with reward 21.0 for model 0 --------
# Actor loss: -0.1711, Critic loss: 0.0338
# Total steps taken during training: 61439
# -------- Episode 7300 ended with reward 11.0 for model 0 --------
# Actor loss: -1.4929, Critic loss: 2.4699
# Total steps taken during training: 62370
# -------- Episode 7400 ended with reward 10.0 for model 0 --------
# Actor loss: -2.1908, Critic loss: 4.5596
# Total steps taken during training: 63178
# -------- Episode 7500 ended with reward 11.0 for model 0 --------
# Actor loss: 0.0113, Critic loss: 0.0001
# Total steps taken during training: 63995
# -------- Episode 7600 ended with reward 6.0 for model 0 --------
# Actor loss: 0.6443, Critic loss: 0.4476
# Total steps taken during training: 64898
# -------- Episode 7700 ended with reward 9.0 for model 0 --------
# Actor loss: 0.7747, Critic loss: 0.5421
# Total steps taken during training: 65706
# -------- Episode 7800 ended with reward 15.0 for model 0 --------
# Actor loss: -1.6345, Critic loss: 1.6626
# Total steps taken during training: 66652
# -------- Episode 7900 ended with reward 7.0 for model 0 --------
# Actor loss: -0.9250, Critic loss: 0.8976
# Total steps taken during training: 67470
# -------- Episode 8000 ended with reward 5.0 for model 0 --------
# Actor loss: -0.2682, Critic loss: 0.0648
# Total steps taken during training: 68337
# -------- Episode 8100 ended with reward 9.0 for model 0 --------
# Actor loss: -1.2303, Critic loss: 1.7396
# Total steps taken during training: 69140
# -------- Episode 8200 ended with reward 17.0 for model 0 --------
# Actor loss: -0.3557, Critic loss: 0.0753
# Total steps taken during training: 70077
# -------- Episode 8300 ended with reward 18.0 for model 0 --------
# Actor loss: -0.1881, Critic loss: 0.0078
# Total steps taken during training: 70934
# -------- Episode 8400 ended with reward 5.0 for model 0 --------
# Actor loss: -0.0435, Critic loss: 0.0015
# Total steps taken during training: 71769
# -------- Episode 8500 ended with reward 6.0 for model 0 --------
# Actor loss: 0.0419, Critic loss: 0.0021
# Total steps taken during training: 72684
# -------- Episode 8600 ended with reward 13.0 for model 0 --------
# Actor loss: -1.7779, Critic loss: 3.2963
# Total steps taken during training: 73685
# -------- Episode 8700 ended with reward 11.0 for model 0 --------
# Actor loss: -0.0023, Critic loss: 0.0000
# Total steps taken during training: 74534
# -------- Episode 8800 ended with reward 11.0 for model 0 --------
# Actor loss: -0.2045, Critic loss: 0.0250
# Total steps taken during training: 75489
# -------- Episode 8900 ended with reward 5.0 for model 0 --------
# Actor loss: 0.0429, Critic loss: 0.0020
# Total steps taken during training: 76376
# -------- Episode 9000 ended with reward 5.0 for model 0 --------
# Actor loss: -0.1131, Critic loss: 0.0144
# Total steps taken during training: 77216
# -------- Episode 9100 ended with reward 7.0 for model 0 --------
# Actor loss: -2.1034, Critic loss: 3.2993
# Total steps taken during training: 78106
# -------- Episode 9200 ended with reward 6.0 for model 0 --------
# Actor loss: -2.3417, Critic loss: 4.6855
# Total steps taken during training: 79000
# -------- Episode 9300 ended with reward 3.0 for model 0 --------
# Actor loss: 0.0251, Critic loss: 0.0004
# Total steps taken during training: 79942
# -------- Episode 9400 ended with reward 14.0 for model 0 --------
# Actor loss: -6.7878, Critic loss: 9.6296
# Total steps taken during training: 80764
# -------- Episode 9500 ended with reward 13.0 for model 0 --------
# Actor loss: -0.4255, Critic loss: 0.1270
# Total steps taken during training: 81632
# -------- Episode 9600 ended with reward 10.0 for model 0 --------
# Actor loss: -0.8585, Critic loss: 0.5924
# Total steps taken during training: 82572
# -------- Episode 9700 ended with reward 9.0 for model 0 --------
# Actor loss: -0.2682, Critic loss: 0.0705
# Total steps taken during training: 83416
# -------- Episode 9800 ended with reward 7.0 for model 0 --------
# Actor loss: -1.6904, Critic loss: 3.1821
# Total steps taken during training: 84273
# -------- Episode 9900 ended with reward 5.0 for model 0 --------
# Actor loss: -0.2199, Critic loss: 0.0195
# Total steps taken during training: 85161
# -------- Episode 10000 ended with reward 18.0 for model 0 --------
# Actor loss: -1.3359, Critic loss: 1.2432
# Total steps taken during training: 85971
# -------- Episode 10100 ended with reward 4.0 for model 0 --------
# Actor loss: -0.8669, Critic loss: 0.8954
# Total steps taken during training: 86997
# -------- Episode 10200 ended with reward 13.0 for model 0 --------
# Actor loss: -0.3450, Critic loss: 0.0743
# Total steps taken during training: 87790
# -------- Episode 10300 ended with reward 8.0 for model 0 --------
# Actor loss: -0.3715, Critic loss: 0.1530
# Total steps taken during training: 88676
# -------- Episode 10400 ended with reward 12.0 for model 0 --------
# Actor loss: -0.5771, Critic loss: 0.1229
# Total steps taken during training: 89470
# -------- Episode 10500 ended with reward 7.0 for model 0 --------
# Actor loss: -0.1834, Critic loss: 0.0401
# Total steps taken during training: 90302
# -------- Episode 10600 ended with reward 7.0 for model 0 --------
# Actor loss: -1.2196, Critic loss: 1.0698
# Total steps taken during training: 91112
# -------- Episode 10700 ended with reward 5.0 for model 0 --------
# Actor loss: 0.2365, Critic loss: 0.0253
# Total steps taken during training: 92064
# -------- Episode 10800 ended with reward 4.0 for model 0 --------
# Actor loss: 0.5085, Critic loss: 0.2054
# Total steps taken during training: 92827
# -------- Episode 10900 ended with reward 13.0 for model 0 --------
# Actor loss: -3.7519, Critic loss: 6.5504
# Total steps taken during training: 93700
# -------- Episode 11000 ended with reward 8.0 for model 0 --------
# Actor loss: -2.3345, Critic loss: 4.4918
# Total steps taken during training: 94524
# -------- Episode 11100 ended with reward 9.0 for model 0 --------
# Actor loss: -1.2361, Critic loss: 0.9634
# Total steps taken during training: 95362
# -------- Episode 11200 ended with reward 4.0 for model 0 --------
# Actor loss: -1.6034, Critic loss: 0.7738
# Total steps taken during training: 96140
# -------- Episode 11300 ended with reward 5.0 for model 0 --------
# Actor loss: 0.1309, Critic loss: 0.0110
# Total steps taken during training: 97000
# -------- Episode 11400 ended with reward 3.0 for model 0 --------
# Actor loss: -0.7048, Critic loss: 0.3261
# Total steps taken during training: 97799
# -------- Episode 11500 ended with reward 4.0 for model 0 --------
# Actor loss: -0.3605, Critic loss: 0.1492
# Total steps taken during training: 98697
# -------- Episode 11600 ended with reward 12.0 for model 0 --------
# Actor loss: -2.3891, Critic loss: 2.8405
# Total steps taken during training: 99564
# -------- Episode 11700 ended with reward 13.0 for model 0 --------
# Actor loss: -3.2234, Critic loss: 0.9926
# Total steps taken during training: 100468
# -------- Episode 11800 ended with reward 4.0 for model 0 --------
# Actor loss: -0.5830, Critic loss: 0.1316
# Total steps taken during training: 101377
# -------- Episode 11900 ended with reward 13.0 for model 0 --------
# Actor loss: -3.5894, Critic loss: 10.1425
# Total steps taken during training: 102259
# -------- Episode 12000 ended with reward 7.0 for model 0 --------
# Actor loss: 0.0146, Critic loss: 0.0003
# Total steps taken during training: 103170
# -------- Episode 12100 ended with reward 8.0 for model 0 --------
# Actor loss: -0.8161, Critic loss: 0.3388
# Total steps taken during training: 104002
# -------- Episode 12200 ended with reward 3.0 for model 0 --------
# Actor loss: -3.7590, Critic loss: 0.6429
# Total steps taken during training: 104822
# -------- Episode 12300 ended with reward 6.0 for model 0 --------
# Actor loss: -0.8032, Critic loss: 0.7422
# Total steps taken during training: 105693
# -------- Episode 12400 ended with reward 12.0 for model 0 --------
# Actor loss: -4.2778, Critic loss: 6.0708
# Total steps taken during training: 106542
# -------- Episode 12500 ended with reward 7.0 for model 0 --------
# Actor loss: -0.6248, Critic loss: 0.4683
# Total steps taken during training: 107392
# -------- Episode 12600 ended with reward 20.0 for model 0 --------
# Actor loss: -0.0495, Critic loss: 0.0024
# Total steps taken during training: 108315
# -------- Episode 12700 ended with reward 16.0 for model 0 --------
# Actor loss: -0.9681, Critic loss: 0.0747
# Total steps taken during training: 109140
# -------- Episode 12800 ended with reward 11.0 for model 0 --------
# Actor loss: -2.3585, Critic loss: 4.6507
# Total steps taken during training: 110009
# -------- Episode 12900 ended with reward 7.0 for model 0 --------
# Actor loss: -2.6830, Critic loss: 2.4343
# Total steps taken during training: 110832
# -------- Episode 13000 ended with reward 9.0 for model 0 --------
# Actor loss: -0.6343, Critic loss: 0.1625
# Total steps taken during training: 111696
# -------- Episode 13100 ended with reward 7.0 for model 0 --------
# Actor loss: -0.0791, Critic loss: 0.0011
# Total steps taken during training: 112579
# -------- Episode 13200 ended with reward 3.0 for model 0 --------
# Actor loss: 0.0357, Critic loss: 0.0006
# Total steps taken during training: 113457
# -------- Episode 13300 ended with reward 7.0 for model 0 --------
# Actor loss: 0.2236, Critic loss: 0.0499
# Total steps taken during training: 114262
# -------- Episode 13400 ended with reward 20.0 for model 0 --------
# Actor loss: 0.0762, Critic loss: 0.0063
# Total steps taken during training: 115103
# -------- Episode 13500 ended with reward 6.0 for model 0 --------
# Actor loss: 0.6347, Critic loss: 0.4778
# Total steps taken during training: 116004
# -------- Episode 13600 ended with reward 4.0 for model 0 --------
# Actor loss: -0.5945, Critic loss: 0.3730
# Total steps taken during training: 116855
# -------- Episode 13700 ended with reward 5.0 for model 0 --------
# Actor loss: 0.8012, Critic loss: 0.1296
# Total steps taken during training: 117725
# -------- Episode 13800 ended with reward 5.0 for model 0 --------
# Actor loss: 0.1690, Critic loss: 0.0290
# Total steps taken during training: 118627
# -------- Episode 13900 ended with reward 8.0 for model 0 --------
# Actor loss: -1.2864, Critic loss: 0.6376
# Total steps taken during training: 119499
# -------- Episode 14000 ended with reward 7.0 for model 0 --------
# Actor loss: -3.0339, Critic loss: 2.5438
# Total steps taken during training: 120401
# -------- Episode 14100 ended with reward 20.0 for model 0 --------
# Actor loss: -0.6243, Critic loss: 0.4682
# Total steps taken during training: 121259
# -------- Episode 14200 ended with reward 5.0 for model 0 --------
# Actor loss: 0.0742, Critic loss: 0.0042
# Total steps taken during training: 122143
# -------- Episode 14300 ended with reward 6.0 for model 0 --------
# Actor loss: -4.2466, Critic loss: 3.7836
# Total steps taken during training: 123018
# -------- Episode 14400 ended with reward 4.0 for model 0 --------
# Actor loss: 0.1017, Critic loss: 0.0039
# Total steps taken during training: 123816
# -------- Episode 14500 ended with reward 7.0 for model 0 --------
# Actor loss: -1.2046, Critic loss: 0.9559
# Total steps taken during training: 124691
# -------- Episode 14600 ended with reward 5.0 for model 0 --------
# Actor loss: 0.0214, Critic loss: 0.0003
# Total steps taken during training: 125483
# -------- Episode 14700 ended with reward 24.0 for model 0 --------
# Actor loss: 0.8656, Critic loss: 0.1489
# Total steps taken during training: 126401
# -------- Episode 14800 ended with reward 14.0 for model 0 --------
# Actor loss: 0.2464, Critic loss: 0.0239
# Total steps taken during training: 127340
# -------- Episode 14900 ended with reward 9.0 for model 0 --------
# Actor loss: 0.2561, Critic loss: 0.0563
# Total steps taken during training: 128122
# -------- Episode 15000 ended with reward 6.0 for model 0 --------
# Actor loss: -0.1238, Critic loss: 0.0181
# Total steps taken during training: 128957
# -------- Episode 15100 ended with reward 7.0 for model 0 --------
# Actor loss: -2.5637, Critic loss: 3.1975
# Total steps taken during training: 129797
# -------- Episode 15200 ended with reward 5.0 for model 0 --------
# Actor loss: 0.0609, Critic loss: 0.0039
# Total steps taken during training: 130590
# -------- Episode 15300 ended with reward 14.0 for model 0 --------
# Actor loss: -0.4139, Critic loss: 0.2048
# Total steps taken during training: 131440
# -------- Episode 15400 ended with reward 10.0 for model 0 --------
# Actor loss: -1.1361, Critic loss: 1.5334
# Total steps taken during training: 132413
# -------- Episode 15500 ended with reward 7.0 for model 0 --------
# Actor loss: -2.0760, Critic loss: 0.5223
# Total steps taken during training: 133174
# -------- Episode 15600 ended with reward 7.0 for model 0 --------
# Actor loss: -1.1938, Critic loss: 1.3225
# Total steps taken during training: 133964
# -------- Episode 15700 ended with reward 21.0 for model 0 --------
# Actor loss: 0.1859, Critic loss: 0.0106
# Total steps taken during training: 134844
# -------- Episode 15800 ended with reward 14.0 for model 0 --------
# Actor loss: -1.2771, Critic loss: 0.7475
# Total steps taken during training: 135683
# -------- Episode 15900 ended with reward 21.0 for model 0 --------
# Actor loss: -2.4964, Critic loss: 7.2615
# Total steps taken during training: 136595
# -------- Episode 16000 ended with reward 6.0 for model 0 --------
# Actor loss: 0.2068, Critic loss: 0.0212
# Total steps taken during training: 137510
# -------- Episode 16100 ended with reward 7.0 for model 0 --------
# Actor loss: -0.1750, Critic loss: 0.0366
# Total steps taken during training: 138350
# -------- Episode 16200 ended with reward 6.0 for model 0 --------
# Actor loss: -0.9036, Critic loss: 0.8632
# Total steps taken during training: 139301
# -------- Episode 16300 ended with reward 6.0 for model 0 --------
# Actor loss: 0.0756, Critic loss: 0.0068
# Total steps taken during training: 140190
# -------- Episode 16400 ended with reward 4.0 for model 0 --------
# Actor loss: 0.6784, Critic loss: 0.5479
# Total steps taken during training: 141010
# -------- Episode 16500 ended with reward 8.0 for model 0 --------
# Actor loss: -6.3038, Critic loss: 1.2802
# Total steps taken during training: 141807
# -------- Episode 16600 ended with reward 13.0 for model 0 --------
# Actor loss: -1.4582, Critic loss: 2.1025
# Total steps taken during training: 142706
# -------- Episode 16700 ended with reward 12.0 for model 0 --------
# Actor loss: 0.1210, Critic loss: 0.0176
# Total steps taken during training: 143566
# -------- Episode 16800 ended with reward 5.0 for model 0 --------
# Actor loss: -1.3545, Critic loss: 0.3390
# Total steps taken during training: 144512
# -------- Episode 16900 ended with reward 5.0 for model 0 --------
# Actor loss: -0.3126, Critic loss: 0.0628
# Total steps taken during training: 145345
# -------- Episode 17000 ended with reward 6.0 for model 0 --------
# Actor loss: -0.2017, Critic loss: 0.0264
# Total steps taken during training: 146198
# -------- Episode 17100 ended with reward 5.0 for model 0 --------
# Actor loss: -1.1428, Critic loss: 1.3878
# Total steps taken during training: 147098
# -------- Episode 17200 ended with reward 15.0 for model 0 --------
# Actor loss: -0.0610, Critic loss: 0.0044
# Total steps taken during training: 147964
# -------- Episode 17300 ended with reward 10.0 for model 0 --------
# Actor loss: -0.3547, Critic loss: 0.1233
# Total steps taken during training: 148912
# -------- Episode 17400 ended with reward 13.0 for model 0 --------
# Actor loss: -1.4776, Critic loss: 0.3384
# Total steps taken during training: 149863
# -------- Episode 17500 ended with reward 4.0 for model 0 --------
# Actor loss: -0.2878, Critic loss: 0.0945
# Total steps taken during training: 150771
# -------- Episode 17600 ended with reward 7.0 for model 0 --------
# Actor loss: 0.2417, Critic loss: 0.0260
# Total steps taken during training: 151584
# -------- Episode 17700 ended with reward 6.0 for model 0 --------
# Actor loss: -0.4476, Critic loss: 0.2422
# Total steps taken during training: 152473
# -------- Episode 17800 ended with reward 8.0 for model 0 --------
# Actor loss: -0.3534, Critic loss: 0.1395
# Total steps taken during training: 153370
# -------- Episode 17900 ended with reward 9.0 for model 0 --------
# Actor loss: -0.7562, Critic loss: 0.2500
# Total steps taken during training: 154307
# -------- Episode 18000 ended with reward 11.0 for model 0 --------
# Actor loss: 0.3463, Critic loss: 0.0321
# Total steps taken during training: 155101
# -------- Episode 18100 ended with reward 14.0 for model 0 --------
# Actor loss: 0.3460, Critic loss: 0.0955
# Total steps taken during training: 155979
# -------- Episode 18200 ended with reward 7.0 for model 0 --------
# Actor loss: -1.3600, Critic loss: 1.0874
# Total steps taken during training: 156877
# -------- Episode 18300 ended with reward 4.0 for model 0 --------
# Actor loss: -0.9427, Critic loss: 1.0541
# Total steps taken during training: 157714
# -------- Episode 18400 ended with reward 6.0 for model 0 --------
# Actor loss: -1.0801, Critic loss: 1.3628
# Total steps taken during training: 158541
# -------- Episode 18500 ended with reward 4.0 for model 0 --------
# Actor loss: -0.7286, Critic loss: 0.4547
# Total steps taken during training: 159409
# -------- Episode 18600 ended with reward 16.0 for model 0 --------
# Actor loss: -1.9531, Critic loss: 4.0391
# Total steps taken during training: 160280
# -------- Episode 18700 ended with reward 6.0 for model 0 --------
# Actor loss: -1.0206, Critic loss: 0.2343
# Total steps taken during training: 161097
# -------- Episode 18800 ended with reward 6.0 for model 0 --------
# Actor loss: 3.1614, Critic loss: 0.4548
# Total steps taken during training: 161959
# -------- Episode 18900 ended with reward 8.0 for model 0 --------
# Actor loss: -0.3819, Critic loss: 0.1630
# Total steps taken during training: 162787
# -------- Episode 19000 ended with reward 4.0 for model 0 --------
# Actor loss: -0.2018, Critic loss: 0.0269
# Total steps taken during training: 163610
# -------- Episode 19100 ended with reward 6.0 for model 0 --------
# Actor loss: -0.6288, Critic loss: 0.4039
# Total steps taken during training: 164511
# -------- Episode 19200 ended with reward 7.0 for model 0 --------
# Actor loss: -0.3835, Critic loss: 0.1777
# Total steps taken during training: 165354
# -------- Episode 19300 ended with reward 14.0 for model 0 --------
# Actor loss: -0.3042, Critic loss: 0.1118
# Total steps taken during training: 166268
# -------- Episode 19400 ended with reward 5.0 for model 0 --------
# Actor loss: 0.4757, Critic loss: 0.0250
# Total steps taken during training: 167134
# -------- Episode 19500 ended with reward 4.0 for model 0 --------
# Actor loss: 0.8140, Critic loss: 0.2767
# Total steps taken during training: 167911
# -------- Episode 19600 ended with reward 15.0 for model 0 --------
# Actor loss: -3.6064, Critic loss: 4.8274
# Total steps taken during training: 168787
# -------- Episode 19700 ended with reward 4.0 for model 0 --------
# Actor loss: 0.3632, Critic loss: 0.0331
# Total steps taken during training: 169556
# -------- Episode 19800 ended with reward 5.0 for model 0 --------
# Actor loss: -0.1434, Critic loss: 0.0125
# Total steps taken during training: 170479
# -------- Episode 19900 ended with reward 5.0 for model 0 --------
# Actor loss: 0.2535, Critic loss: 0.0761
# Total steps taken during training: 171351
# -------- Episode 20000 ended with reward 3.0 for model 0 --------
# Actor loss: -0.0965, Critic loss: 0.0027
# Total steps taken during training: 172217
# -------- Episode 20100 ended with reward 6.0 for model 0 --------
# Actor loss: -1.5888, Critic loss: 1.5076
# Total steps taken during training: 173113
# -------- Episode 20200 ended with reward 6.0 for model 0 --------
# Actor loss: 0.3658, Critic loss: 0.0707
# Total steps taken during training: 173944
# -------- Episode 20300 ended with reward 9.0 for model 0 --------
# Actor loss: -2.9436, Critic loss: 4.4314
# Total steps taken during training: 174881
# -------- Episode 20400 ended with reward 6.0 for model 0 --------
# Actor loss: 0.1475, Critic loss: 0.0240
# Total steps taken during training: 175730
# -------- Episode 20500 ended with reward 11.0 for model 0 --------
# Actor loss: -1.2658, Critic loss: 0.2511
# Total steps taken during training: 176564
# -------- Episode 20600 ended with reward 6.0 for model 0 --------
# Actor loss: -0.3124, Critic loss: 0.1064
# Total steps taken during training: 177455
# -------- Episode 20700 ended with reward 4.0 for model 0 --------
# Actor loss: -0.9497, Critic loss: 0.5376
# Total steps taken during training: 178341
# -------- Episode 20800 ended with reward 6.0 for model 0 --------
# Actor loss: -1.0283, Critic loss: 0.6008
# Total steps taken during training: 179199
# -------- Episode 20900 ended with reward 9.0 for model 0 --------
# Actor loss: -0.7876, Critic loss: 0.0335
# Total steps taken during training: 180053
# -------- Episode 21000 ended with reward 7.0 for model 0 --------
# Actor loss: -4.3316, Critic loss: 11.7116
# Total steps taken during training: 180986
# -------- Episode 21100 ended with reward 8.0 for model 0 --------
# Actor loss: -0.0626, Critic loss: 0.0044
# Total steps taken during training: 181919
# -------- Episode 21200 ended with reward 7.0 for model 0 --------
# Actor loss: -0.1006, Critic loss: 0.0121
# Total steps taken during training: 182714
# -------- Episode 21300 ended with reward 18.0 for model 0 --------
# Actor loss: -0.8089, Critic loss: 0.7813
# Total steps taken during training: 183578
# -------- Episode 21400 ended with reward 13.0 for model 0 --------
# Actor loss: -5.7068, Critic loss: 4.8751
# Total steps taken during training: 184440
# -------- Episode 21500 ended with reward 6.0 for model 0 --------
# Actor loss: 1.1481, Critic loss: 0.1161
# Total steps taken during training: 185296
# -------- Episode 21600 ended with reward 4.0 for model 0 --------
# Actor loss: -0.6370, Critic loss: 0.0706
# Total steps taken during training: 186130
# -------- Episode 21700 ended with reward 9.0 for model 0 --------
# Actor loss: -0.5569, Critic loss: 0.2401
# Total steps taken during training: 187018
# -------- Episode 21800 ended with reward 13.0 for model 0 --------
# Actor loss: -1.3549, Critic loss: 1.2699
# Total steps taken during training: 187804
# -------- Episode 21900 ended with reward 8.0 for model 0 --------
# Actor loss: -0.1362, Critic loss: 0.0199
# Total steps taken during training: 188676
# -------- Episode 22000 ended with reward 9.0 for model 0 --------
# Actor loss: 0.6161, Critic loss: 0.0999
# Total steps taken during training: 189597
# -------- Episode 22100 ended with reward 5.0 for model 0 --------
# Actor loss: -0.0644, Critic loss: 0.0007
# Total steps taken during training: 190546
# -------- Episode 22200 ended with reward 5.0 for model 0 --------
# Actor loss: -1.1835, Critic loss: 0.9339
# Total steps taken during training: 191405
# -------- Episode 22300 ended with reward 6.0 for model 0 --------
# Actor loss: -0.7776, Critic loss: 0.0736
# Total steps taken during training: 192241
# -------- Episode 22400 ended with reward 13.0 for model 0 --------
# Actor loss: -1.2391, Critic loss: 1.6156
# Total steps taken during training: 193050
# -------- Episode 22500 ended with reward 10.0 for model 0 --------
# Actor loss: -0.5626, Critic loss: 0.1659
# Total steps taken during training: 193873
# -------- Episode 22600 ended with reward 5.0 for model 0 --------
# Actor loss: -1.4783, Critic loss: 0.1176
# Total steps taken during training: 194710
# -------- Episode 22700 ended with reward 12.0 for model 0 --------
# Actor loss: -0.2529, Critic loss: 0.0216
# Total steps taken during training: 195577
# -------- Episode 22800 ended with reward 6.0 for model 0 --------
# Actor loss: -1.3231, Critic loss: 0.2958
# Total steps taken during training: 196457
# -------- Episode 22900 ended with reward 4.0 for model 0 --------
# Actor loss: -0.2487, Critic loss: 0.0719
# Total steps taken during training: 197234
# -------- Episode 23000 ended with reward 27.0 for model 0 --------
# Actor loss: -0.1663, Critic loss: 0.0154
# Total steps taken during training: 198172
# -------- Episode 23100 ended with reward 7.0 for model 0 --------
# Actor loss: -1.5100, Critic loss: 0.3668
# Total steps taken during training: 199101
# -------- Episode 23200 ended with reward 9.0 for model 0 --------
# Actor loss: -0.6937, Critic loss: 0.2995
# Total steps taken during training: 199971
# -------- Episode 23300 ended with reward 8.0 for model 0 --------
# Actor loss: 0.0327, Critic loss: 0.0011
# Total steps taken during training: 200802
# -------- Episode 23400 ended with reward 7.0 for model 0 --------
# Actor loss: -0.1784, Critic loss: 0.0136
# Total steps taken during training: 201660
# -------- Episode 23500 ended with reward 7.0 for model 0 --------
# Actor loss: -0.5070, Critic loss: 0.3098
# Total steps taken during training: 202539
# -------- Episode 23600 ended with reward 7.0 for model 0 --------
# Actor loss: -1.3042, Critic loss: 1.4758
# Total steps taken during training: 203409
# -------- Episode 23700 ended with reward 8.0 for model 0 --------
# Actor loss: -0.2166, Critic loss: 0.0487
# Total steps taken during training: 204260
# -------- Episode 23800 ended with reward 11.0 for model 0 --------
# Actor loss: 0.3101, Critic loss: 0.0717
# Total steps taken during training: 205109
# -------- Episode 23900 ended with reward 12.0 for model 0 --------
# Actor loss: -11.3007, Critic loss: 9.3946
# Total steps taken during training: 205954
# -------- Episode 24000 ended with reward 4.0 for model 0 --------
# Actor loss: -0.8812, Critic loss: 0.1094
# Total steps taken during training: 206834
# -------- Episode 24100 ended with reward 15.0 for model 0 --------
# Actor loss: -0.4862, Critic loss: 0.1720
# Total steps taken during training: 207747
# -------- Episode 24200 ended with reward 9.0 for model 0 --------
# Actor loss: -1.5510, Critic loss: 0.4304
# Total steps taken during training: 208635
# -------- Episode 24300 ended with reward 15.0 for model 0 --------
# Actor loss: -0.1228, Critic loss: 0.0133
# Total steps taken during training: 209485
# -------- Episode 24400 ended with reward 16.0 for model 0 --------
# Actor loss: 0.3420, Critic loss: 0.1417
# Total steps taken during training: 210407
# -------- Episode 24500 ended with reward 6.0 for model 0 --------
# Actor loss: 0.6314, Critic loss: 0.0883
# Total steps taken during training: 211234
# -------- Episode 24600 ended with reward 5.0 for model 0 --------
# Actor loss: -0.7830, Critic loss: 0.5914
# Total steps taken during training: 212058
# -------- Episode 24700 ended with reward 15.0 for model 0 --------
# Actor loss: -0.4795, Critic loss: 0.0885
# Total steps taken during training: 212933
# -------- Episode 24800 ended with reward 14.0 for model 0 --------
# Actor loss: 0.0198, Critic loss: 0.0002
# Total steps taken during training: 213699
# -------- Episode 24900 ended with reward 4.0 for model 0 --------
# Actor loss: -7.3408, Critic loss: 2.5445
# Total steps taken during training: 214512
# -------- Episode 25000 ended with reward 4.0 for model 0 --------
# Actor loss: -0.3477, Critic loss: 0.1436
# Total steps taken during training: 215377
# -------- Episode 25100 ended with reward 4.0 for model 0 --------
# Actor loss: -0.0027, Critic loss: 0.0000
# Total steps taken during training: 216240
# -------- Episode 25200 ended with reward 9.0 for model 0 --------
# Actor loss: -0.5374, Critic loss: 0.3134
# Total steps taken during training: 217111
# -------- Episode 25300 ended with reward 5.0 for model 0 --------
# Actor loss: -0.7349, Critic loss: 0.6284
# Total steps taken during training: 217966
# -------- Episode 25400 ended with reward 9.0 for model 0 --------
# Actor loss: 0.0968, Critic loss: 0.0050
# Total steps taken during training: 218760
# -------- Episode 25500 ended with reward 5.0 for model 0 --------
# Actor loss: -0.3521, Critic loss: 0.0191
# Total steps taken during training: 219630
# -------- Episode 25600 ended with reward 14.0 for model 0 --------
# Actor loss: -4.0804, Critic loss: 9.3502
# Total steps taken during training: 220636
# -------- Episode 25700 ended with reward 6.0 for model 0 --------
# Actor loss: -1.1132, Critic loss: 1.0705
# Total steps taken during training: 221606
# -------- Episode 25800 ended with reward 9.0 for model 0 --------
# Actor loss: -0.7471, Critic loss: 0.6581
# Total steps taken during training: 222415
# -------- Episode 25900 ended with reward 5.0 for model 0 --------
# Actor loss: -1.5049, Critic loss: 1.1366
# Total steps taken during training: 223223
# -------- Episode 26000 ended with reward 4.0 for model 0 --------
# Actor loss: -0.1713, Critic loss: 0.0285
# Total steps taken during training: 224033
# -------- Episode 26100 ended with reward 4.0 for model 0 --------
# Actor loss: -0.6090, Critic loss: 0.4496
# Total steps taken during training: 224852
# -------- Episode 26200 ended with reward 10.0 for model 0 --------
# Actor loss: -0.2354, Critic loss: 0.0576
# Total steps taken during training: 225664
# -------- Episode 26300 ended with reward 3.0 for model 0 --------
# Actor loss: -0.4958, Critic loss: 0.1469
# Total steps taken during training: 226506
# -------- Episode 26400 ended with reward 6.0 for model 0 --------
# Actor loss: -1.9201, Critic loss: 2.4847
# Total steps taken during training: 227314
# -------- Episode 26500 ended with reward 6.0 for model 0 --------
# Actor loss: -2.8882, Critic loss: 4.1580
# Total steps taken during training: 228158
# -------- Episode 26600 ended with reward 6.0 for model 0 --------
# Actor loss: -2.0304, Critic loss: 2.3207
# Total steps taken during training: 229074
# -------- Episode 26700 ended with reward 6.0 for model 0 --------
# Actor loss: -1.5546, Critic loss: 1.7083
# Total steps taken during training: 229930
# -------- Episode 26800 ended with reward 5.0 for model 0 --------
# Actor loss: -0.6487, Critic loss: 0.4910
# Total steps taken during training: 230768
# -------- Episode 26900 ended with reward 9.0 for model 0 --------
# Actor loss: -2.2919, Critic loss: 0.7064
# Total steps taken during training: 231595
# -------- Episode 27000 ended with reward 11.0 for model 0 --------
# Actor loss: 0.3769, Critic loss: 0.1652
# Total steps taken during training: 232449
# -------- Episode 27100 ended with reward 4.0 for model 0 --------
# Actor loss: -0.1051, Critic loss: 0.0036
# Total steps taken during training: 233272
# -------- Episode 27200 ended with reward 8.0 for model 0 --------
# Actor loss: 0.2979, Critic loss: 0.0995
# Total steps taken during training: 234154
# -------- Episode 27300 ended with reward 8.0 for model 0 --------
# Actor loss: -1.0290, Critic loss: 0.3766
# Total steps taken during training: 235043
# -------- Episode 27400 ended with reward 6.0 for model 0 --------
# Actor loss: 0.4363, Critic loss: 0.0102
# Total steps taken during training: 235895
# -------- Episode 27500 ended with reward 6.0 for model 0 --------
# Actor loss: -0.0205, Critic loss: 0.0002
# Total steps taken during training: 236774
# -------- Episode 27600 ended with reward 4.0 for model 0 --------
# Actor loss: -0.8487, Critic loss: 0.4037
# Total steps taken during training: 237652
# -------- Episode 27700 ended with reward 24.0 for model 0 --------
# Actor loss: -1.2851, Critic loss: 1.7749
# Total steps taken during training: 238434
# -------- Episode 27800 ended with reward 8.0 for model 0 --------
# Actor loss: -1.0096, Critic loss: 0.4312
# Total steps taken during training: 239264
# -------- Episode 27900 ended with reward 6.0 for model 0 --------
# Actor loss: -1.4079, Critic loss: 2.1700
# Total steps taken during training: 240094
# -------- Episode 28000 ended with reward 8.0 for model 0 --------
# Actor loss: -1.9834, Critic loss: 0.4919
# Total steps taken during training: 240941
# -------- Episode 28100 ended with reward 12.0 for model 0 --------
# Actor loss: -0.1088, Critic loss: 0.0082
# Total steps taken during training: 241801
# -------- Episode 28200 ended with reward 19.0 for model 0 --------
# Actor loss: -0.5675, Critic loss: 0.3231
# Total steps taken during training: 242732
# -------- Episode 28300 ended with reward 4.0 for model 0 --------
# Actor loss: -1.6013, Critic loss: 1.2623
# Total steps taken during training: 243586
# -------- Episode 28400 ended with reward 11.0 for model 0 --------
# Actor loss: -0.4598, Critic loss: 0.2305
# Total steps taken during training: 244397
# -------- Episode 28500 ended with reward 5.0 for model 0 --------
# Actor loss: -0.7225, Critic loss: 0.5754
# Total steps taken during training: 245215
# -------- Episode 28600 ended with reward 4.0 for model 0 --------
# Actor loss: -2.3018, Critic loss: 1.0923
# Total steps taken during training: 246037
# -------- Episode 28700 ended with reward 10.0 for model 0 --------
# Actor loss: -0.0820, Critic loss: 0.0074
# Total steps taken during training: 246869
# -------- Episode 28800 ended with reward 6.0 for model 0 --------
# Actor loss: 0.0879, Critic loss: 0.0056
# Total steps taken during training: 247787
# -------- Episode 28900 ended with reward 5.0 for model 0 --------
# Actor loss: -0.9293, Critic loss: 0.2225
# Total steps taken during training: 248630
# -------- Episode 29000 ended with reward 24.0 for model 0 --------
# Actor loss: -0.5208, Critic loss: 0.2922
# Total steps taken during training: 249573
# -------- Episode 29100 ended with reward 9.0 for model 0 --------
# Actor loss: -1.3049, Critic loss: 0.4388
# Total steps taken during training: 250347
# -------- Episode 29200 ended with reward 7.0 for model 0 --------
# Actor loss: -4.8334, Critic loss: 9.4455
# Total steps taken during training: 251171
# -------- Episode 29300 ended with reward 5.0 for model 0 --------
# Actor loss: -0.2356, Critic loss: 0.0672
# Total steps taken during training: 251976
# -------- Episode 29400 ended with reward 15.0 for model 0 --------
# Actor loss: -4.1072, Critic loss: 20.3831
# Total steps taken during training: 252861
# -------- Episode 29500 ended with reward 6.0 for model 0 --------
# Actor loss: 0.2821, Critic loss: 0.0429
# Total steps taken during training: 253667
# -------- Episode 29600 ended with reward 4.0 for model 0 --------
# Actor loss: -0.5406, Critic loss: 0.2531
# Total steps taken during training: 254441
# -------- Episode 29700 ended with reward 16.0 for model 0 --------
# Actor loss: -0.3867, Critic loss: 0.1551
# Total steps taken during training: 255296
# -------- Episode 29800 ended with reward 4.0 for model 0 --------
# Actor loss: 0.2179, Critic loss: 0.0441
# Total steps taken during training: 256126
# -------- Episode 29900 ended with reward 11.0 for model 0 --------
# Actor loss: -0.9737, Critic loss: 0.1982
# Total steps taken during training: 256980
# -------- Episode 30000 ended with reward 13.0 for model 0 --------
# Actor loss: -0.1433, Critic loss: 0.0072
# Total steps taken during training: 257873
# -------- Episode 30100 ended with reward 10.0 for model 0 --------
# Actor loss: -0.5986, Critic loss: 0.3394
# Total steps taken during training: 258678
# -------- Episode 30200 ended with reward 10.0 for model 0 --------
# Actor loss: -0.1861, Critic loss: 0.0254
# Total steps taken during training: 259539
# -------- Episode 30300 ended with reward 4.0 for model 0 --------
# Actor loss: -0.5772, Critic loss: 0.1669
# Total steps taken during training: 260395
# -------- Episode 30400 ended with reward 3.0 for model 0 --------
# Actor loss: -0.0171, Critic loss: 0.0001
# Total steps taken during training: 261210
# -------- Episode 30500 ended with reward 7.0 for model 0 --------
# Actor loss: -1.1001, Critic loss: 1.2370
# Total steps taken during training: 262032
# -------- Episode 30600 ended with reward 12.0 for model 0 --------
# Actor loss: -0.3859, Critic loss: 0.1798
# Total steps taken during training: 262904
# -------- Episode 30700 ended with reward 11.0 for model 0 --------
# Actor loss: -0.9797, Critic loss: 0.3640
# Total steps taken during training: 263776
# -------- Episode 30800 ended with reward 7.0 for model 0 --------
# Actor loss: 0.5600, Critic loss: 0.2526
# Total steps taken during training: 264627
# -------- Episode 30900 ended with reward 8.0 for model 0 --------
# Actor loss: 0.2050, Critic loss: 0.0490
# Total steps taken during training: 265510
# -------- Episode 31000 ended with reward 12.0 for model 0 --------
# Actor loss: 0.0762, Critic loss: 0.0026
# Total steps taken during training: 266382
# -------- Episode 31100 ended with reward 6.0 for model 0 --------
# Actor loss: -0.5193, Critic loss: 0.1843
# Total steps taken during training: 267251
# -------- Episode 31200 ended with reward 5.0 for model 0 --------
# Actor loss: -0.9167, Critic loss: 0.9752
# Total steps taken during training: 268127
# -------- Episode 31300 ended with reward 3.0 for model 0 --------
# Actor loss: -0.5997, Critic loss: 0.3683
# Total steps taken during training: 268979
# -------- Episode 31400 ended with reward 5.0 for model 0 --------
# Actor loss: -0.7900, Critic loss: 0.4539
# Total steps taken during training: 269799
# -------- Episode 31500 ended with reward 8.0 for model 0 --------
# Actor loss: -0.5406, Critic loss: 0.1421
# Total steps taken during training: 270670
# -------- Episode 31600 ended with reward 7.0 for model 0 --------
# Actor loss: -0.7970, Critic loss: 0.4967
# Total steps taken during training: 271526
# -------- Episode 31700 ended with reward 4.0 for model 0 --------
# Actor loss: 0.1880, Critic loss: 0.0415
# Total steps taken during training: 272371
# -------- Episode 31800 ended with reward 11.0 for model 0 --------
# Actor loss: 0.2677, Critic loss: 0.0636
# Total steps taken during training: 273247
# -------- Episode 31900 ended with reward 7.0 for model 0 --------
# Actor loss: 0.3228, Critic loss: 0.1200
# Total steps taken during training: 274139
# -------- Episode 32000 ended with reward 6.0 for model 0 --------
# Actor loss: -1.4910, Critic loss: 2.4299
# Total steps taken during training: 274912
# -------- Episode 32100 ended with reward 5.0 for model 0 --------
# Actor loss: -0.4541, Critic loss: 0.1795
# Total steps taken during training: 275774
# -------- Episode 32200 ended with reward 6.0 for model 0 --------
# Actor loss: 0.0709, Critic loss: 0.0033
# Total steps taken during training: 276577
# -------- Episode 32300 ended with reward 11.0 for model 0 --------
# Actor loss: -3.6819, Critic loss: 14.3880
# Total steps taken during training: 277482
# -------- Episode 32400 ended with reward 4.0 for model 0 --------
# ...
# Actor loss: 0.1306, Critic loss: 0.0165
# Total steps taken during training: 422686
# -------- Episode 58700 ended with reward 26.0 for model 2 --------
# Actor loss: -0.9295, Critic loss: 0.3886
# Total steps taken during training: 423434
# -------- Episode 58800 ended with reward 6.0 for model 2 --------
# Actor loss: -0.4558, Critic loss: 0.1557
# Total steps taken during training: 424183
# -------- Episode 58900 ended with reward 5.0 for model 2 --------
# Actor loss: -0.3308, Critic loss: 0.0733
# Total steps taken during training: 424912
# -------- Episode 59000 ended with reward 17.0 for model 2 --------
# Actor loss: -2.0806, Critic loss: 2.4223
# Total steps taken during training: 425642
# -------- Episode 59100 ended with reward 6.0 for model 2 --------
# Actor loss: -0.4019, Critic loss: 0.1721
# Total steps taken during training: 426311
# -------- Episode 59200 ended with reward 5.0 for model 2 --------
# Actor loss: 0.9762, Critic loss: 0.4953
# Total steps taken during training: 426996
# -------- Episode 59300 ended with reward 7.0 for model 2 --------
# Actor loss: 0.2939, Critic loss: 0.0115
# Total steps taken during training: 427757
# -------- Episode 59400 ended with reward 15.0 for model 2 --------
# Actor loss: -0.2968, Critic loss: 0.0978
# Total steps taken during training: 428450
# -------- Episode 59500 ended with reward 4.0 for model 2 --------
# Actor loss: -0.1583, Critic loss: 0.0251
# Total steps taken during training: 429165
# -------- Episode 59600 ended with reward 7.0 for model 2 --------
# Actor loss: 0.2409, Critic loss: 0.0072
# Total steps taken during training: 429907
# -------- Episode 59700 ended with reward 5.0 for model 2 --------
# Actor loss: 0.1934, Critic loss: 0.0348
# Total steps taken during training: 430598
# -------- Episode 59800 ended with reward 5.0 for model 2 --------
# Actor loss: -0.6639, Critic loss: 0.2746
# Total steps taken during training: 431304
# -------- Episode 59900 ended with reward 7.0 for model 2 --------
# Actor loss: -0.1464, Critic loss: 0.0225
# Total steps taken during training: 432021
# -------- Episode 60000 ended with reward 15.0 for model 2 --------
# Actor loss: 0.2224, Critic loss: 0.0217
# Total steps taken during training: 432759
# -------- Episode 60100 ended with reward 7.0 for model 2 --------
# Actor loss: -1.2984, Critic loss: 0.2847
# Total steps taken during training: 433457
# -------- Episode 60200 ended with reward 8.0 for model 2 --------
# Actor loss: -0.5719, Critic loss: 0.3223
# Total steps taken during training: 434179
# -------- Episode 60300 ended with reward 6.0 for model 2 --------
# Actor loss: -0.8693, Critic loss: 0.1425
# Total steps taken during training: 434924
# -------- Episode 60400 ended with reward 4.0 for model 2 --------
# Actor loss: -0.6858, Critic loss: 0.5207
# Total steps taken during training: 435620
# -------- Episode 60500 ended with reward 4.0 for model 2 --------
# Actor loss: -1.2142, Critic loss: 0.1140
# Total steps taken during training: 436316
# -------- Episode 60600 ended with reward 5.0 for model 2 --------
# Actor loss: -0.5383, Critic loss: 0.0336
# Total steps taken during training: 437089
# -------- Episode 60700 ended with reward 8.0 for model 2 --------
# Actor loss: -0.4604, Critic loss: 0.2381
# Total steps taken during training: 437880
# -------- Episode 60800 ended with reward 4.0 for model 2 --------
# Actor loss: -0.4688, Critic loss: 0.2339
# Total steps taken during training: 438592
# -------- Episode 60900 ended with reward 12.0 for model 2 --------
# Actor loss: -0.0629, Critic loss: 0.0048
# Total steps taken during training: 439332
# -------- Episode 61000 ended with reward 10.0 for model 2 --------
# Actor loss: -0.8344, Critic loss: 0.8194
# Total steps taken during training: 440076
# -------- Episode 61100 ended with reward 4.0 for model 2 --------
# Actor loss: 0.1644, Critic loss: 0.0108
# Total steps taken during training: 440787
# -------- Episode 61200 ended with reward 7.0 for model 2 --------
# Actor loss: -1.5200, Critic loss: 0.4335
# Total steps taken during training: 441544
# -------- Episode 61300 ended with reward 4.0 for model 2 --------
# Actor loss: 0.0244, Critic loss: 0.0004
# Total steps taken during training: 442264
# -------- Episode 61400 ended with reward 4.0 for model 2 --------
# Actor loss: -1.2645, Critic loss: 0.2769
# Total steps taken during training: 443003
# -------- Episode 61500 ended with reward 4.0 for model 2 --------
# Actor loss: 0.6036, Critic loss: 0.0252
# Total steps taken during training: 443756
# -------- Episode 61600 ended with reward 6.0 for model 2 --------
# Actor loss: 0.0740, Critic loss: 0.0058
# Total steps taken during training: 444467
# -------- Episode 61700 ended with reward 5.0 for model 2 --------
# Actor loss: -0.2156, Critic loss: 0.0181
# Total steps taken during training: 445231
# -------- Episode 61800 ended with reward 6.0 for model 2 --------
# Actor loss: 0.0487, Critic loss: 0.0029
# Total steps taken during training: 445954
# -------- Episode 61900 ended with reward 6.0 for model 2 --------
# Actor loss: -0.0341, Critic loss: 0.0014
# Total steps taken during training: 446650
# -------- Episode 62000 ended with reward 12.0 for model 2 --------
# Actor loss: 0.3579, Critic loss: 0.0220
# Total steps taken during training: 447311
# -------- Episode 62100 ended with reward 5.0 for model 2 --------
# Actor loss: -0.3530, Critic loss: 0.1411
# Total steps taken during training: 447970
# -------- Episode 62200 ended with reward 4.0 for model 2 --------
# Actor loss: -0.3639, Critic loss: 0.1014
# Total steps taken during training: 448663
# -------- Episode 62300 ended with reward 6.0 for model 2 --------
# Actor loss: 0.8893, Critic loss: 0.3535
# Total steps taken during training: 449307
# -------- Episode 62400 ended with reward 5.0 for model 2 --------
# Actor loss: 0.0805, Critic loss: 0.0074
# Total steps taken during training: 450085
# -------- Episode 62500 ended with reward 6.0 for model 2 --------
# Actor loss: -0.5041, Critic loss: 0.1995
# Total steps taken during training: 450860
# -------- Episode 62600 ended with reward 7.0 for model 2 --------
# Actor loss: -0.4437, Critic loss: 0.0773
# Total steps taken during training: 451608
# -------- Episode 62700 ended with reward 12.0 for model 2 --------
# Actor loss: -0.1550, Critic loss: 0.0273
# Total steps taken during training: 452382
# -------- Episode 62800 ended with reward 4.0 for model 2 --------
# Actor loss: -0.6237, Critic loss: 0.4434
# Total steps taken during training: 453104
# -------- Episode 62900 ended with reward 6.0 for model 2 --------
# Actor loss: -0.2720, Critic loss: 0.0874
# Total steps taken during training: 453841
# -------- Episode 63000 ended with reward 11.0 for model 2 --------
# Actor loss: -4.0078, Critic loss: 19.4395
# Total steps taken during training: 454596
# -------- Episode 63100 ended with reward 3.0 for model 2 --------
# Actor loss: 0.7792, Critic loss: 0.4717
# Total steps taken during training: 455362
# -------- Episode 63200 ended with reward 7.0 for model 2 --------
# Actor loss: 0.3074, Critic loss: 0.0882
# Total steps taken during training: 456110
# -------- Episode 63300 ended with reward 9.0 for model 2 --------
# Actor loss: -1.0029, Critic loss: 0.7244
# Total steps taken during training: 456887
# -------- Episode 63400 ended with reward 5.0 for model 2 --------
# Actor loss: -0.3294, Critic loss: 0.1196
# Total steps taken during training: 457653
# -------- Episode 63500 ended with reward 9.0 for model 2 --------
# Actor loss: -0.9878, Critic loss: 0.6681
# Total steps taken during training: 458369
# -------- Episode 63600 ended with reward 7.0 for model 2 --------
# Actor loss: -0.6017, Critic loss: 0.1453
# Total steps taken during training: 459089
# -------- Episode 63700 ended with reward 4.0 for model 2 --------
# Actor loss: -0.3241, Critic loss: 0.1155
# Total steps taken during training: 459759
# -------- Episode 63800 ended with reward 7.0 for model 2 --------
# Actor loss: -0.3898, Critic loss: 0.0961
# Total steps taken during training: 460477
# -------- Episode 63900 ended with reward 5.0 for model 2 --------
# Actor loss: -0.3906, Critic loss: 0.1667
# Total steps taken during training: 461173
# -------- Episode 64000 ended with reward 5.0 for model 2 --------
# Actor loss: -0.0493, Critic loss: 0.0029
# Total steps taken during training: 461913
# -------- Episode 64100 ended with reward 6.0 for model 2 --------
# Actor loss: -0.8519, Critic loss: 0.8752
# Total steps taken during training: 462661
# -------- Episode 64200 ended with reward 9.0 for model 2 --------
# Actor loss: -0.2785, Critic loss: 0.0902
# Total steps taken during training: 463392
# -------- Episode 64300 ended with reward 4.0 for model 2 --------
# Actor loss: -0.6874, Critic loss: 0.4409
# Total steps taken during training: 464133
# -------- Episode 64400 ended with reward 4.0 for model 2 --------
# Actor loss: 0.0432, Critic loss: 0.0017
# Total steps taken during training: 464854
# -------- Episode 64500 ended with reward 6.0 for model 2 --------
# Actor loss: 0.2126, Critic loss: 0.0235
# Total steps taken during training: 465589
# -------- Episode 64600 ended with reward 11.0 for model 2 --------
# Actor loss: -1.7338, Critic loss: 1.9058
# Total steps taken during training: 466283
# -------- Episode 64700 ended with reward 15.0 for model 2 --------
# Actor loss: -1.2163, Critic loss: 0.6261
# Total steps taken during training: 467066
# -------- Episode 64800 ended with reward 5.0 for model 2 --------
# Actor loss: -1.2905, Critic loss: 0.7126
# Total steps taken during training: 467822
# -------- Episode 64900 ended with reward 7.0 for model 2 --------
# Actor loss: -1.2450, Critic loss: 1.0143
# Total steps taken during training: 468609
# -------- Episode 65000 ended with reward 7.0 for model 2 --------
# Actor loss: -4.8526, Critic loss: 3.4789
# Total steps taken during training: 469364
# -------- Episode 65100 ended with reward 36.0 for model 2 --------
# Actor loss: -0.8989, Critic loss: 0.4831
# Total steps taken during training: 470116
# -------- Episode 65200 ended with reward 7.0 for model 2 --------
# Actor loss: -1.8674, Critic loss: 4.0330
# Total steps taken during training: 470889
# -------- Episode 65300 ended with reward 6.0 for model 2 --------
# Actor loss: 0.3966, Critic loss: 0.1129
# Total steps taken during training: 471595
# -------- Episode 65400 ended with reward 8.0 for model 2 --------
# Actor loss: -0.0732, Critic loss: 0.0034
# Total steps taken during training: 472339
# -------- Episode 65500 ended with reward 9.0 for model 2 --------
# Actor loss: -0.6128, Critic loss: 0.4441
# Total steps taken during training: 473112
# -------- Episode 65600 ended with reward 5.0 for model 2 --------
# Actor loss: 0.1866, Critic loss: 0.0403
# Total steps taken during training: 473796
# -------- Episode 65700 ended with reward 11.0 for model 2 --------
# Actor loss: 0.3554, Critic loss: 0.0811
# Total steps taken during training: 474545
# -------- Episode 65800 ended with reward 9.0 for model 2 --------
# Actor loss: -2.3123, Critic loss: 0.8980
# Total steps taken during training: 475297
# -------- Episode 65900 ended with reward 23.0 for model 2 --------
# Actor loss: -1.6122, Critic loss: 2.7141
# Total steps taken during training: 476091
# -------- Episode 66000 ended with reward 6.0 for model 2 --------
# Actor loss: -0.3382, Critic loss: 0.0539
# Total steps taken during training: 476877
# -------- Episode 66100 ended with reward 21.0 for model 2 --------
# Actor loss: -0.4738, Critic loss: 0.2259
# Total steps taken during training: 477684
# -------- Episode 66200 ended with reward 4.0 for model 2 --------
# Actor loss: 0.0707, Critic loss: 0.0061
# Total steps taken during training: 478325
# -------- Episode 66300 ended with reward 4.0 for model 2 --------
# Actor loss: 0.1217, Critic loss: 0.0125
# Total steps taken during training: 479059
# -------- Episode 66400 ended with reward 4.0 for model 2 --------
# Actor loss: 0.1630, Critic loss: 0.0248
# Total steps taken during training: 479753
# -------- Episode 66500 ended with reward 5.0 for model 2 --------
# Actor loss: 1.5254, Critic loss: 0.1575
# Total steps taken during training: 480470
# -------- Episode 66600 ended with reward 7.0 for model 2 --------
# Actor loss: 0.6106, Critic loss: 0.1654
# Total steps taken during training: 481166
# -------- Episode 66700 ended with reward 4.0 for model 2 --------
# Actor loss: 0.0349, Critic loss: 0.0012
# Total steps taken during training: 481873
# -------- Episode 66800 ended with reward 7.0 for model 2 --------
# Actor loss: -8.6695, Critic loss: 10.7575
# Total steps taken during training: 482619
# -------- Episode 66900 ended with reward 5.0 for model 2 --------
# Actor loss: -0.4246, Critic loss: 0.1207
# Total steps taken during training: 483355
# -------- Episode 67000 ended with reward 4.0 for model 2 --------
# Actor loss: -0.1050, Critic loss: 0.0106
# Total steps taken during training: 484108
# -------- Episode 67100 ended with reward 6.0 for model 2 --------
# Actor loss: 0.0231, Critic loss: 0.0003
# Total steps taken during training: 484852
# -------- Episode 67200 ended with reward 7.0 for model 2 --------
# Actor loss: -0.8148, Critic loss: 0.8003
# Total steps taken during training: 485546
# -------- Episode 67300 ended with reward 4.0 for model 2 --------
# Actor loss: -0.4795, Critic loss: 0.0663
# Total steps taken during training: 486271
# -------- Episode 67400 ended with reward 10.0 for model 2 --------
# Actor loss: -0.2972, Critic loss: 0.1038
# Total steps taken during training: 486982
# -------- Episode 67500 ended with reward 4.0 for model 2 --------
# Actor loss: -0.4052, Critic loss: 0.1279
# Total steps taken during training: 487627
# -------- Episode 67600 ended with reward 9.0 for model 2 --------
# Actor loss: -0.1261, Critic loss: 0.0089
# Total steps taken during training: 488310
# -------- Episode 67700 ended with reward 5.0 for model 2 --------
# Actor loss: 0.2155, Critic loss: 0.0555
# Total steps taken during training: 489001
# -------- Episode 67800 ended with reward 11.0 for model 2 --------
# Actor loss: -0.0951, Critic loss: 0.0089
# Total steps taken during training: 489738
# -------- Episode 67900 ended with reward 8.0 for model 2 --------
# Actor loss: -0.7096, Critic loss: 0.3940
# Total steps taken during training: 490417
# -------- Episode 68000 ended with reward 7.0 for model 2 --------
# Actor loss: -1.2831, Critic loss: 0.2162
# Total steps taken during training: 491184
# -------- Episode 68100 ended with reward 8.0 for model 2 --------
# Actor loss: -0.1723, Critic loss: 0.0336
# Total steps taken during training: 491888
# -------- Episode 68200 ended with reward 4.0 for model 2 --------
# Actor loss: -0.5004, Critic loss: 0.1343
# Total steps taken during training: 492643
# -------- Episode 68300 ended with reward 4.0 for model 2 --------
# Actor loss: -0.3817, Critic loss: 0.1288
# Total steps taken during training: 493340
# -------- Episode 68400 ended with reward 11.0 for model 2 --------
# Actor loss: -0.9588, Critic loss: 0.4656
# Total steps taken during training: 494053
# -------- Episode 68500 ended with reward 4.0 for model 2 --------
# Actor loss: -0.5117, Critic loss: 0.1812
# Total steps taken during training: 494732
# -------- Episode 68600 ended with reward 6.0 for model 2 --------
# Actor loss: -0.0341, Critic loss: 0.0009
# Total steps taken during training: 495495
# -------- Episode 68700 ended with reward 4.0 for model 2 --------
# Actor loss: -0.2152, Critic loss: 0.0527
# Total steps taken during training: 496213
# -------- Episode 68800 ended with reward 4.0 for model 2 --------
# Actor loss: -0.5319, Critic loss: 0.1166
# Total steps taken during training: 496965
# -------- Episode 68900 ended with reward 4.0 for model 2 --------
# Actor loss: -3.1620, Critic loss: 2.0047
# Total steps taken during training: 497751
# -------- Episode 69000 ended with reward 10.0 for model 2 --------
# Actor loss: 0.0213, Critic loss: 0.0005
# Total steps taken during training: 498458
# -------- Episode 69100 ended with reward 9.0 for model 2 --------
# Actor loss: -0.6740, Critic loss: 0.5423
# Total steps taken during training: 499192
# -------- Episode 69200 ended with reward 8.0 for model 2 --------
# Actor loss: -0.1506, Critic loss: 0.0174
# Total steps taken during training: 499869
# Reached total training budget of 500000 steps ----> Stopping training at episode 69217

# %% [markdown]
# ### training logging info
#
# - losses and rewards are every 1k step
# - evaluation rewards and value_trajectories are every 20k steps

# %%
# Get stats 
min_critic_losses, max_critic_losses, avg_critic_losses = get_stats(all_critic_losses)
min_actor_losses, max_actor_losses, avg_actor_losses = get_stats(all_actor_losses)
min_episode_rewards, max_episode_rewards, avg_episode_rewards = get_stats(all_episode_rewards)

save_plots = False
folder_name = 'agent5'

# Plot stats 
plot_stats(save_plots, folder_name, min_critic_losses, max_critic_losses, avg_critic_losses, title='Critic Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_stats(save_plots, folder_name, min_actor_losses, max_actor_losses, avg_actor_losses, title='Actor Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_stats(save_plots, folder_name, min_episode_rewards, max_episode_rewards, avg_episode_rewards, title='Episode Rewards', ylabel='Reward', xlabel='Steps (every 1000 steps)')

# %%
# Plot smoothed stats 
window_size = 10

plot_smoothed_stats(save_plots, folder_name, min_critic_losses, max_critic_losses, avg_critic_losses, window_size, title='Critic Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_smoothed_stats(save_plots, folder_name, min_actor_losses, max_actor_losses, avg_actor_losses, window_size, title='Actor Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_smoothed_stats(save_plots, folder_name, min_episode_rewards, max_episode_rewards, avg_episode_rewards, window_size, title='Episode Rewards', ylabel='Reward', xlabel='Steps (every 1000 steps)')

# %%
# Get stats for evaluation rewards
min_eval_rew, max_eval_rew, avg_eval_rew = get_stats(all_evaluation_reward_means)

# Plot stats
plot_smoothed_stats(save_plots, folder_name, min_eval_rew, max_eval_rew, avg_eval_rew, window_size, title='Evaluation Episode Rewards',ylabel='Reward',xlabel='Steps (every 20k steps)')

# %%
plot_and_save_trajectories(save_plots, folder_name, all_evaluation_value_trajectories, x_range=[0, 500], y_range=[0, 150])

# %% [markdown]
# ### saving agents and data

# %%
folder_name = "data/data_agent5"

os.makedirs(folder_name, exist_ok=True)

# # Save all_* dictionaries
with open(folder_name+'/all_dicts.pkl', 'wb') as f:
    pickle.dump([all_critic_losses, all_actor_losses, all_episode_rewards, \
                 all_evaluation_reward_means, all_evaluation_reward_stds, all_evaluation_value_trajectories], f)

# Save agent3 dictionary
with open(folder_name+'/agent.pkl', 'wb') as f:
    pickle.dump(agent, f)

# # Save seed list used for training
with open(folder_name+'/seeds.pkl', 'wb') as f:
    pickle.dump(seeds, f)
