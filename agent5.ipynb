# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import collections
import pickle
import os


from training import *
from models import *
from A2C_agent import *
from helpers import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Load data and agents
#
# To produce all plots

# %%
# Load all_* dictionaries
agent_name = "chose the agent" # for example 'agent5'
with open('data/'+agent_name+'_data/all_dicts.pkl', 'rb') as f:
    all_critic_losses, all_actor_losses, all_episode_rewards, \
        all_evaluation_reward_means, all_evaluation_reward_stds, all_evaluation_value_trajectories = pickle.load(f)

# Load agent1 dictionary
with open('data/'+agent_name+'_data/agent1.pkl', 'rb') as f:
    agent1 = pickle.load(f)

# %% [markdown]
# # 4.2 Agent 5: Evaluating the CartPole agent in the new environment
# ### vanilla A2C (fully-online, n=1,k=1), continuous action space

# %%
# hyperparameters
stochastic_rewards = False
continuous = True
k=1
n=1
lr_actor=1e-5
lr_critic=1e-3
total_steps_budget = 500000
device = "cpu"
seeds = [734289, 324, 80435]

agent, \
all_critic_losses, all_actor_losses, all_episode_rewards, \
all_evaluation_reward_means, all_evaluation_reward_stds, all_evaluation_value_trajectories \
= training_loop(k, n, continuous, seeds, lr_actor, lr_critic, total_steps_budget, stochastic_rewards=False, device="cpu")
# Out:
# -------- Episode 100 ended with reward 4.0 for model 0 --------
# Actor loss: -2.8093, Critic loss: 6.2952
# Total steps taken during training: 920
# -------- Episode 200 ended with reward 40.0 for model 0 --------
# Actor loss: -12.1754, Critic loss: 94.7951
# Total steps taken during training: 2130
# -------- Episode 300 ended with reward 7.0 for model 0 --------
# Actor loss: -0.6463, Critic loss: 0.1643
# Total steps taken during training: 3767
# -------- Episode 400 ended with reward 17.0 for model 0 --------
# Actor loss: -6.0591, Critic loss: 12.9024
# Total steps taken during training: 5681
# -------- Episode 500 ended with reward 16.0 for model 0 --------
# Actor loss: -3.0732, Critic loss: 5.2188
# Total steps taken during training: 7633
# -------- Episode 600 ended with reward 42.0 for model 0 --------
# Actor loss: -15.1458, Critic loss: 64.0213
# Total steps taken during training: 10324
# -------- Episode 700 ended with reward 28.0 for model 0 --------
# Actor loss: -6.3631, Critic loss: 14.8491
# Total steps taken during training: 13415
# -------- Episode 800 ended with reward 64.0 for model 0 --------
# Actor loss: -5.9629, Critic loss: 35.9061
# Total steps taken during training: 17650
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 253.00, Std reward: 36.74, total steps: 20000
# ----     Evaluation finished        ----
# -------- Episode 900 ended with reward 62.0 for model 0 --------
# Actor loss: 5.4660, Critic loss: 21.4636
# Total steps taken during training: 23860
# -------- Episode 1000 ended with reward 56.0 for model 0 --------
# Actor loss: -3.5566, Critic loss: 8.3367
# Total steps taken during training: 31914
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 159.90, Std reward: 4.85, total steps: 40000
# ----     Evaluation finished        ----
# -------- Episode 1100 ended with reward 202.0 for model 0 --------
# Actor loss: -9.7802, Critic loss: 48.4028
# Total steps taken during training: 42566
# -------- Episode 1200 ended with reward 48.0 for model 0 --------
# Actor loss: -85.3379, Critic loss: 1323.8545
# Total steps taken during training: 53873
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 265.00, Std reward: 8.43, total steps: 60000
# ----     Evaluation finished        ----
# -------- Episode 1300 ended with reward 203.0 for model 0 --------
# Actor loss: -25.7400, Critic loss: 104.0145
# Total steps taken during training: 66867
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 80000
# ----     Evaluation finished        ----
# -------- Episode 1400 ended with reward 214.0 for model 0 --------
# Actor loss: -118.0924, Critic loss: 934.5635
# Total steps taken during training: 88521
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 100000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 120000
# ----     Evaluation finished        ----
# -------- Episode 1500 ended with reward 1000.0 for model 0 --------
# Actor loss: 0.0828, Critic loss: 0.0095
# Total steps taken during training: 137918
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 140000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 160000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 180000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 200000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 220000
# ----     Evaluation finished        ----
# -------- Episode 1600 ended with reward 1000.0 for model 0 --------
# Actor loss: -0.0012, Critic loss: 0.0000
# Total steps taken during training: 221300
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 240000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 260000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 280000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 300000
# ----     Evaluation finished        ----
# -------- Episode 1700 ended with reward 1000.0 for model 0 --------
# Actor loss: -0.0000, Critic loss: 0.0000
# Total steps taken during training: 314279
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 320000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 340000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 360000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 380000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 400000
# ----     Evaluation finished        ----
# -------- Episode 1800 ended with reward 1000.0 for model 0 --------
# Actor loss: -0.0000, Critic loss: 0.0000
# Total steps taken during training: 411425
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 420000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 440000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 460000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 480000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 0 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 500000
# ----     Evaluation finished        ----
# Reached total training budget of 500000 steps ----> Stopping training at episode 1890
# -------- Episode 100 ended with reward 6.0 for model 1 --------
# Actor loss: -3.0241, Critic loss: 3.6864
# Total steps taken during training: 845
# -------- Episode 200 ended with reward 6.0 for model 1 --------
# Actor loss: -6.1718, Critic loss: 22.4226
# Total steps taken during training: 1910
# -------- Episode 300 ended with reward 10.0 for model 1 --------
# Actor loss: -3.6126, Critic loss: 12.2820
# Total steps taken during training: 3220
# -------- Episode 400 ended with reward 12.0 for model 1 --------
# Actor loss: -5.1947, Critic loss: 5.3510
# Total steps taken during training: 4737
# -------- Episode 500 ended with reward 6.0 for model 1 --------
# Actor loss: -4.8647, Critic loss: 9.5465
# Total steps taken during training: 6862
# -------- Episode 600 ended with reward 10.0 for model 1 --------
# Actor loss: -12.4585, Critic loss: 30.6047
# Total steps taken during training: 9419
# -------- Episode 700 ended with reward 21.0 for model 1 --------
# Actor loss: -3.9643, Critic loss: 8.8890
# Total steps taken during training: 12716
# -------- Episode 800 ended with reward 62.0 for model 1 --------
# Actor loss: -13.9777, Critic loss: 233.0150
# Total steps taken during training: 17290
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 212.10, Std reward: 24.98, total steps: 20000
# ----     Evaluation finished        ----
# -------- Episode 900 ended with reward 76.0 for model 1 --------
# Actor loss: -30.5978, Critic loss: 484.7034
# Total steps taken during training: 23116
# -------- Episode 1000 ended with reward 84.0 for model 1 --------
# Actor loss: -3.1072, Critic loss: 10.8363
# Total steps taken during training: 31107
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 115.90, Std reward: 3.05, total steps: 40000
# ----     Evaluation finished        ----
# -------- Episode 1100 ended with reward 106.0 for model 1 --------
# Actor loss: -20.8910, Critic loss: 283.2764
# Total steps taken during training: 40640
# -------- Episode 1200 ended with reward 122.0 for model 1 --------
# Actor loss: -2.4431, Critic loss: 6.2616
# Total steps taken during training: 49769
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 288.70, Std reward: 27.63, total steps: 60000
# ----     Evaluation finished        ----
# -------- Episode 1300 ended with reward 51.0 for model 1 --------
# Actor loss: -5.8096, Critic loss: 12.0922
# Total steps taken during training: 60953
# -------- Episode 1400 ended with reward 70.0 for model 1 --------
# Actor loss: -22.7714, Critic loss: 560.9916
# Total steps taken during training: 72738
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 989.80, Std reward: 14.63, total steps: 80000
# ----     Evaluation finished        ----
# -------- Episode 1500 ended with reward 116.0 for model 1 --------
# Actor loss: -42.7853, Critic loss: 1810.9813
# Total steps taken during training: 87163
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 198.90, Std reward: 5.87, total steps: 100000
# ----     Evaluation finished        ----
# -------- Episode 1600 ended with reward 180.0 for model 1 --------
# Actor loss: -48.5976, Critic loss: 2778.4788
# Total steps taken during training: 105797
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 996.80, Std reward: 8.65, total steps: 120000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 140000
# ----     Evaluation finished        ----
# -------- Episode 1700 ended with reward 1000.0 for model 1 --------
# Actor loss: 0.0895, Critic loss: 0.0043
# Total steps taken during training: 150924
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 160000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 180000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 200000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 220000
# ----     Evaluation finished        ----
# -------- Episode 1800 ended with reward 1000.0 for model 1 --------
# Actor loss: -0.0014, Critic loss: 0.0000
# Total steps taken during training: 235039
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 240000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 260000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 280000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 300000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 320000
# ----     Evaluation finished        ----
# -------- Episode 1900 ended with reward 1000.0 for model 1 --------
# Actor loss: 0.0001, Critic loss: 0.0000
# Total steps taken during training: 331008
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 340000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 360000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 380000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 400000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 420000
# ----     Evaluation finished        ----
# -------- Episode 2000 ended with reward 1000.0 for model 1 --------
# Actor loss: 0.0062, Critic loss: 0.0000
# Total steps taken during training: 426770
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 440000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 460000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 480000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 1 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 500000
# ----     Evaluation finished        ----
# Reached total training budget of 500000 steps ----> Stopping training at episode 2074
# -------- Episode 100 ended with reward 6.0 for model 2 --------
# Actor loss: -0.9109, Critic loss: 0.8057
# Total steps taken during training: 852
# -------- Episode 200 ended with reward 10.0 for model 2 --------
# Actor loss: -7.3921, Critic loss: 52.3631
# Total steps taken during training: 1720
# -------- Episode 300 ended with reward 16.0 for model 2 --------
# Actor loss: -22.1052, Critic loss: 96.3180
# Total steps taken during training: 2831
# -------- Episode 400 ended with reward 17.0 for model 2 --------
# Actor loss: -8.3872, Critic loss: 57.1152
# Total steps taken during training: 4242
# -------- Episode 500 ended with reward 16.0 for model 2 --------
# Actor loss: -2.0349, Critic loss: 3.7535
# Total steps taken during training: 6303
# -------- Episode 600 ended with reward 10.0 for model 2 --------
# Actor loss: -28.3018, Critic loss: 91.8167
# Total steps taken during training: 8744
# -------- Episode 700 ended with reward 15.0 for model 2 --------
# Actor loss: -6.4374, Critic loss: 34.8643
# Total steps taken during training: 11809
# -------- Episode 800 ended with reward 33.0 for model 2 --------
# Actor loss: -7.0999, Critic loss: 57.7641
# Total steps taken during training: 15700
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 104.60, Std reward: 10.34, total steps: 20000
# ----     Evaluation finished        ----
# -------- Episode 900 ended with reward 58.0 for model 2 --------
# Actor loss: -5.5840, Critic loss: 34.1907
# Total steps taken during training: 21251
# -------- Episode 1000 ended with reward 113.0 for model 2 --------
# Actor loss: -69.5254, Critic loss: 979.6496
# Total steps taken during training: 29458
# -------- Episode 1100 ended with reward 32.0 for model 2 --------
# Actor loss: -26.7278, Critic loss: 897.5135
# Total steps taken during training: 38111
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 175.90, Std reward: 7.13, total steps: 40000
# ----     Evaluation finished        ----
# -------- Episode 1200 ended with reward 212.0 for model 2 --------
# Actor loss: -85.0209, Critic loss: 1317.3604
# Total steps taken during training: 48446
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 482.60, Std reward: 27.69, total steps: 60000
# ----     Evaluation finished        ----
# -------- Episode 1300 ended with reward 64.0 for model 2 --------
# Actor loss: 0.3842, Critic loss: 0.0127
# Total steps taken during training: 63485
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 351.60, Std reward: 8.73, total steps: 80000
# ----     Evaluation finished        ----
# -------- Episode 1400 ended with reward 360.0 for model 2 --------
# Actor loss: -14.8647, Critic loss: 27.5406
# Total steps taken during training: 85412
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 100000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 120000
# ----     Evaluation finished        ----
# -------- Episode 1500 ended with reward 101.0 for model 2 --------
# Actor loss: -60.8274, Critic loss: 4698.8813
# Total steps taken during training: 130666
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 140000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 160000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 180000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 200000
# ----     Evaluation finished        ----
# -------- Episode 1600 ended with reward 1000.0 for model 2 --------
# Actor loss: -0.0001, Critic loss: 0.0000
# Total steps taken during training: 211208
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 220000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 240000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 260000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 280000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 300000
# ----     Evaluation finished        ----
# -------- Episode 1700 ended with reward 1000.0 for model 2 --------
# Actor loss: 0.0085, Critic loss: 0.0001
# Total steps taken during training: 302703
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 320000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 340000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 360000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 380000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 400000
# ----     Evaluation finished        ----
# -------- Episode 1800 ended with reward 1000.0 for model 2 --------
# Actor loss: 0.0278, Critic loss: 0.0009
# Total steps taken during training: 400020
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 420000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 440000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 460000
# ----     Evaluation finished        ----
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 480000
# ----     Evaluation finished        ----
# -------- Episode 1900 ended with reward 1000.0 for model 2 --------
# Actor loss: 0.0001, Critic loss: 0.0000
# Total steps taken during training: 498856
# ---- Proceeding to evaluate model 2 ... ----
# Mean reward: 1000.00, Std reward: 0.00, total steps: 500000
# ----     Evaluation finished        ----
# Reached total training budget of 500000 steps ----> Stopping training at episode 1902

# %% [markdown]
# ### training logging info
#
# - losses and rewards are every 1k step
# - evaluation rewards and value_trajectories are every 20k steps

# %%
(1-0.99**1000)/(1-0.99)
# Out:
# 99.99568287525884

# %%
# Get stats 
min_critic_losses, max_critic_losses, avg_critic_losses = get_stats(all_critic_losses)
min_actor_losses, max_actor_losses, avg_actor_losses = get_stats(all_actor_losses)
min_episode_rewards, max_episode_rewards, avg_episode_rewards = get_stats(all_episode_rewards)

save_plots = True
folder_name = 'agent5'

# Plot stats 
plot_stats(save_plots, folder_name, min_critic_losses, max_critic_losses, avg_critic_losses, title='Critic Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_stats(save_plots, folder_name, min_actor_losses, max_actor_losses, avg_actor_losses, title='Actor Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_stats(save_plots, folder_name, min_episode_rewards, max_episode_rewards, avg_episode_rewards, title='Episode Rewards', ylabel='Reward', xlabel='Steps (every 1000 steps)')

# %%
# Plot smoothed stats 
window_size = 10

plot_smoothed_stats(save_plots, folder_name, min_critic_losses, max_critic_losses, avg_critic_losses, window_size, title='Smoothed Critic Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_smoothed_stats(save_plots, folder_name, min_actor_losses, max_actor_losses, avg_actor_losses, window_size, title='Smoothed Actor Losses', ylabel='Loss', xlabel='Steps (every 1000 steps)')
plot_smoothed_stats(save_plots, folder_name, min_episode_rewards, max_episode_rewards, avg_episode_rewards, window_size, title='Smoothed Episode Rewards', ylabel='Reward', xlabel='Steps (every 1000 steps)')

# %%
# Get stats for evaluation rewards
min_eval_rew, max_eval_rew, avg_eval_rew = get_stats(all_evaluation_reward_means)

# Plot stats
plot_smoothed_stats(save_plots, folder_name, min_eval_rew, max_eval_rew, avg_eval_rew, window_size, title='Evaluation Episode Rewards',ylabel='Reward',xlabel='Steps (every 20k steps)')

# %%
plot_and_save_trajectories(save_plots, folder_name, all_evaluation_value_trajectories, x_range=[0, 500], y_range=[0, 150])

# %% [markdown]
# ### saving agents and data

# %%
folder_name = "data/data_agent5"

os.makedirs(folder_name, exist_ok=True)

# # Save all_* dictionaries
with open(folder_name+'/all_dicts.pkl', 'wb') as f:
    pickle.dump([all_critic_losses, all_actor_losses, all_episode_rewards, \
                 all_evaluation_reward_means, all_evaluation_reward_stds, all_evaluation_value_trajectories], f)

# Save agent3 dictionary
with open(folder_name+'/agent.pkl', 'wb') as f:
    pickle.dump(agent, f)

# # Save seed list used for training
with open(folder_name+'/seeds.pkl', 'wb') as f:
    pickle.dump(seeds, f)
